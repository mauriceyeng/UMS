# %%
import nest_asyncio
nest_asyncio.apply()

import aiohttp
import asyncio
import json
import pandas as pd
from datetime import datetime 
from datetime import timedelta

# UMS app information
ums_base_url = "https://app.edoofa.com/api/1.1/obj"
ums_bearer_token = "786720e8eb68de7054d1149b56cc04f9"
ums_headers = {'Authorization': f'Bearer {ums_bearer_token}'}





# Asynchronous function to fetch data from a table
async def fetch_table_data(session, base_url, headers, table, constraints=None):
    records = []
    cursor = 0
    total_fetched = 0

    while True:
        params = {'limit': 100, 'cursor': cursor}
        if constraints:
            params['constraints'] = json.dumps(constraints)

        api_url = f"{base_url}/{table}"
        print(f"Fetching {table} data from {base_url}... Cursor: {cursor}")

        async with session.get(api_url, headers=headers, params=params) as response:
            if response.status != 200:
                print(f"Failed to fetch data from {table}: {await response.text()}")
                break

            data = await response.json()
            new_records = data['response']['results']
            records.extend(new_records)
            total_fetched += len(new_records)

            print(f"Fetched {len(new_records)} new records, Total fetched: {total_fetched}")

            cursor += 100

            if len(new_records) < 100:
                print(f"Exiting loop, fetched less than 100 records.")
                break

    df = pd.DataFrame(records)
    print(f"Fetched {len(df)} records for {table}.")
    return df



def get_percentage(number_of_present, total_sessions):
    if total_sessions == 0:
        return 0  # Avoid division by zero
    percent = (number_of_present / total_sessions) * 100
    #print(percent)
    return percent

async def check_if_row_exists(student, year, month, ums_avg_att_df):
    # Filtering the ums_avg_att_df to check if there's an existing record for the student
    existing_rows = ums_avg_att_df[
        (ums_avg_att_df['ewyl-group-name'] == student) &
        (ums_avg_att_df['year'] == year) &
        (ums_avg_att_df['month'] == month)
    ]

    if not existing_rows.empty:
        # Assuming '_id' is the column name for the row ID
        return existing_rows['_id'].iloc[0]
    else:
        return False
    
def process_att_summary(combined_df, ums_avg_att_df):
    att_summary_df = pd.DataFrame(columns=['admissions-group-name', 'attendance-percentage', 
                                           'avg-att-percent-till-last-month', 'ewyl-group-name', 
                                           'first-day-of-month', 'month', 'year'])

    combined_df['date'] = pd.to_datetime(combined_df['date'])    
    unique_students = combined_df['admissions-group-name'].unique()

    for student in unique_students:
        print(f"Processing attendance data for student: {student}")  # Debug line to indicate the current student being processed
        student_df = combined_df[combined_df['admissions-group-name'] == student]

        first_date = pd.to_datetime(student_df['date'].min())
        first_day_current_month = first_date.replace(day=1)

        while True:
            this_month_df = student_df[(student_df['date'].dt.year == first_day_current_month.year) &
                                       (student_df['date'].dt.month == first_day_current_month.month)]

            prev_month_df = student_df[student_df['date'] < first_day_current_month]

            total_sessions_this_month = len(this_month_df)
            attended_sessions_this_month = this_month_df['present'].sum()
            attendance_percentage_this_month = get_percentage(attended_sessions_this_month, total_sessions_this_month)

            if prev_month_df.empty:
                avg_att_till_last_month = 0
            else:
                total_sessions_till_last_month = len(prev_month_df)
                attended_sessions_till_last_month = prev_month_df['present'].sum()
                avg_att_till_last_month = get_percentage(attended_sessions_till_last_month, total_sessions_till_last_month)

            new_row = {
                'admissions-group-name': student,
                'attendance-percentage': attendance_percentage_this_month,
                'avg-att-percent-till-last-month': avg_att_till_last_month,
                'ewyl-group-name': student_df['ewyl-group-name'].iloc[0] if not student_df['ewyl-group-name'].empty else 'N/A',
                'first-day-of-month': first_day_current_month.strftime("%Y-%m-%d"),
                'month': first_day_current_month.strftime("%B"),
                'year': first_day_current_month.year
            }
            att_summary_df = pd.concat([att_summary_df, pd.DataFrame([new_row])], ignore_index=True)

            next_month_first_day = (first_day_current_month + pd.offsets.MonthBegin()).normalize()
            first_day_current_month = next_month_first_day
            
            if student_df[student_df['date'] >= first_day_current_month].empty:
                break

    # Save the processed attendance summary data to a CSV file
    att_summary_df.to_csv('attendance_summary.csv', index=False)
    print("Attendance summary data saved to 'attendance_summary.csv'.")

    return att_summary_df





async def main():

    async with aiohttp.ClientSession() as session:
        ums_att_df = await fetch_table_data(session, ums_base_url, ums_headers, "Attendance")
        ums_att_df.to_csv("ums_att_df.csv", index=False)
        ums_avg_att_df = await fetch_table_data(session, ums_base_url, ums_headers, "Attendance-Summary")
        ums_avg_att_df.to_csv("ums_avg_att_df.csv", index=False)
        
        att_summary_df = process_att_summary(ums_att_df, ums_avg_att_df)

        print("Attendance summary processing complete.")
        
await main()

# %%
import nest_asyncio
nest_asyncio.apply()

import aiohttp
import asyncio
import json
import pandas as pd
from datetime import datetime 
from datetime import timedelta


student_df = None
engagement_df = None
ums_att_df = None
ums_avg_att_df = None
ums_upload_avg_att=None

edoofy_base_url = "https://edoofa-portal.bubbleapps.io/api/1.1/obj"
edoofy_bearer_token = "2cde31d8f48919a2db1467cc06a56132"
edoofy_headers = {'Authorization': f'Bearer {edoofy_bearer_token}'}

ums_base_url = "https://app.edoofa.com/version-test/api/1.1/obj"
ums_bearer_token = "786720e8eb68de7054d1149b56cc04f9"
ums_headers = {'Authorization': f'Bearer {ums_bearer_token}'}


async def fetch_table_data(session, base_url, headers, table, constraints=None):
    records = []
    cursor = 0
    total_fetched = 0

    while True:
        params = {'limit': 100, 'cursor': cursor}
        if constraints:
            params['constraints'] = json.dumps(constraints)

        api_url = f"{base_url}/{table}"
        print(f"Fetching {table} data from {base_url}... Cursor: {cursor}")

        async with session.get(api_url, headers=headers, params=params) as response:
            if response.status != 200:
                print(f"Failed to fetch data from {table}: {await response.text()}")
                break

            data = await response.json()
            new_records = data['response']['results']
            records.extend(new_records)
            total_fetched += len(new_records)

            print(f"Fetched {len(new_records)} new records, Total fetched: {total_fetched}")

            cursor += 100

            if len(new_records) < 100:
                print(f"Exiting loop, fetched less than 100 records.")
                break

    df = pd.DataFrame(records)
    print(f"Fetched {len(df)} records for {table}.")
    return df



def create_attendance_row(engagement_record):
    attendance_row = {
        'admissions-group-name': engagement_record['admissions-group-name'],  
        'attendance-type': engagement_record['engagement-type'],  
        'date': engagement_record['engagement-date'],  
        'ewyl-group-name': engagement_record['ewyl-group-name'],  
        'present': engagement_record['daily-attendance'],  
    }

    return attendance_row

async def post_attendance_record(session, url, headers, record):
    try:
        async with session.post(url, headers=headers, json=record) as response:
            if response.status == 200:
                print("Record posted successfully.")
                return await response.json()
            else:
                print(f"Failed to post record: {await response.text()}")
                return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None


async def main():
    async with aiohttp.ClientSession() as session:
        ums_student_df = await fetch_table_data(session, ums_base_url, ums_headers, "Student")
        ums_att_df = await fetch_table_data(session, ums_base_url, ums_headers, "Attendance")  
        student_constraints = [{'key': 'indian-edoofian', 'constraint_type': 'equals', 'value': 'yes'}]
        student_df = await fetch_table_data(session, edoofy_base_url, edoofy_headers, "Student", constraints=student_constraints)
        
        engagement_df = pd.DataFrame()
        for engagement_type in ['IE Call', 'IE Chat', 'Activity', 'Lesson']:
            engagement_data = await fetch_table_data(session, edoofy_base_url, edoofy_headers, "Engagement", [{'key': 'engagement-type', 'constraint_type': 'equals', 'value': engagement_type}])
            engagement_df = pd.concat([engagement_df, engagement_data], ignore_index=True)
        
        engagement_df = pd.merge(engagement_df, student_df[['_id', 'KAM-group-name', 'EWYL-group-name']], left_on='student', right_on='_id', how='left')
        engagement_df.rename(columns={'KAM-group-name': 'admissions-group-name', 'EWYL-group-name': 'ewyl-group-name', '_id_x': '_id'}, inplace=True)
        engagement_df.drop(['_id_y'], axis=1, inplace=True)
        engagement_df.dropna(subset=['admissions-group-name'], inplace=True)
        
        # Convert dates to datetime objects and ensure they are tz-naive
        ums_att_df['date'] = pd.to_datetime(ums_att_df['date']).dt.tz_localize(None)
        engagement_df['engagement-date'] = pd.to_datetime(engagement_df['engagement-date']).dt.tz_localize(None)
        engagement_df['engagement-date'] = pd.to_datetime(engagement_df['engagement-date']) + timedelta(hours=5, minutes=30)
        
        # Create 'comparison-date' in 'ums_att_df' with just the date part
        ums_att_df['date'] = ums_att_df['date'].dt.date
        # Create 'comparison-date' in 'engagement_df' with just the date part
        engagement_df['engagement-date'] = engagement_df['engagement-date'].dt.date
        
        new_attendance_records = []
        
        for _, student in ums_student_df.iterrows():
            admissions_group_name = student['admissions-group-name']
            print(f"Processing admissions group: {admissions_group_name}")

            # Dynamically determine the latest attendance date for each admissions group
            if admissions_group_name in ums_att_df['admissions-group-name'].values:
                group_attendance = ums_att_df[ums_att_df['admissions-group-name'] == admissions_group_name]
                if not group_attendance.empty:
                    latest_attendance_date = group_attendance['date'].max()
                else:
                    latest_attendance_date = pd.Timestamp('1900-01-01')  # Default old date for new admissions groups
            else:
                latest_attendance_date = pd.Timestamp('1900-01-01')  # Default old date for new admissions groups
            print(latest_attendance_date)
            engagements = engagement_df[engagement_df['admissions-group-name'] == admissions_group_name]
            
            for _, engagement in engagements.iterrows():
                if engagement['engagement-date'] > latest_attendance_date:
                    new_row = create_attendance_row(engagement)
                    new_attendance_records.append(new_row)

        new_attendance_df = pd.DataFrame(new_attendance_records)
        """
        # Post new attendance records if any
        if not new_attendance_df.empty:
            new_attendance_df['date'] = new_attendance_df['date'].dt.strftime('%m/%d/%Y') + " 05:30 AM"
            for _, record in new_attendance_df.iterrows():
                admissions_group_name = record['admissions-group-name']
                print(f"Posting attendance for admissions group: {admissions_group_name}")
                url = f"{ums_base_url}/Attendance"
                await post_attendance_record(session, url, ums_headers, record.to_dict())
        else:
            print("No new attendance records to process.")
        
        """
        
        print(new_attendance_df.head())
        return new_attendance_df


await main()
# Out:
# Fetching Student data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 0
# Fetched 100 new records, Total fetched: 100
# Fetching Student data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 100
# Fetched 100 new records, Total fetched: 200
# Fetching Student data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 200
# Fetched 100 new records, Total fetched: 300
# Fetching Student data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 300
# Fetched 100 new records, Total fetched: 400
# Fetching Student data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 400
# Fetched 100 new records, Total fetched: 500
# Fetching Student data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 500
# Fetched 100 new records, Total fetched: 600
# Fetching Student data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 600
# Fetched 100 new records, Total fetched: 700
# Fetching Student data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 700
# Fetched 100 new records, Total fetched: 800
# Fetching Student data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 800
# Fetched 20 new records, Total fetched: 820
# Exiting loop, fetched less than 100 records.
# Fetched 820 records for Student.
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 0
# Fetched 100 new records, Total fetched: 100
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 100
# Fetched 100 new records, Total fetched: 200
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 200
# Fetched 100 new records, Total fetched: 300
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 300
# Fetched 100 new records, Total fetched: 400
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 400
# Fetched 100 new records, Total fetched: 500
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 500
# Fetched 100 new records, Total fetched: 600
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 600
# Fetched 100 new records, Total fetched: 700
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 700
# Fetched 100 new records, Total fetched: 800
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 800
# Fetched 100 new records, Total fetched: 900
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 900
# Fetched 100 new records, Total fetched: 1000
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 1000
# Fetched 100 new records, Total fetched: 1100
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 1100
# Fetched 100 new records, Total fetched: 1200
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 1200
# Fetched 100 new records, Total fetched: 1300
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 1300
# Fetched 100 new records, Total fetched: 1400
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 1400
# Fetched 100 new records, Total fetched: 1500
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 1500
# Fetched 100 new records, Total fetched: 1600
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 1600
# Fetched 100 new records, Total fetched: 1700
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 1700
# Fetched 100 new records, Total fetched: 1800
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 1800
# Fetched 100 new records, Total fetched: 1900
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 1900
# Fetched 100 new records, Total fetched: 2000
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 2000
# Fetched 100 new records, Total fetched: 2100
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 2100
# Fetched 100 new records, Total fetched: 2200
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 2200
# Fetched 100 new records, Total fetched: 2300
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 2300
# Fetched 100 new records, Total fetched: 2400
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 2400
# Fetched 100 new records, Total fetched: 2500
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 2500
# Fetched 100 new records, Total fetched: 2600
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 2600
# Fetched 100 new records, Total fetched: 2700
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 2700
# Fetched 100 new records, Total fetched: 2800
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 2800
# Fetched 100 new records, Total fetched: 2900
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 2900
# Fetched 100 new records, Total fetched: 3000
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 3000
# Fetched 100 new records, Total fetched: 3100
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 3100
# Fetched 100 new records, Total fetched: 3200
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 3200
# Fetched 100 new records, Total fetched: 3300
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 3300
# Fetched 100 new records, Total fetched: 3400
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 3400
# Fetched 100 new records, Total fetched: 3500
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 3500
# Fetched 100 new records, Total fetched: 3600
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 3600
# Fetched 100 new records, Total fetched: 3700
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 3700
# Fetched 100 new records, Total fetched: 3800
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 3800
# Fetched 100 new records, Total fetched: 3900
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 3900
# Fetched 100 new records, Total fetched: 4000
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 4000
# Fetched 100 new records, Total fetched: 4100
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 4100
# Fetched 100 new records, Total fetched: 4200
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 4200
# Fetched 100 new records, Total fetched: 4300
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 4300
# Fetched 100 new records, Total fetched: 4400
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 4400
# Fetched 100 new records, Total fetched: 4500
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 4500
# Fetched 100 new records, Total fetched: 4600
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 4600
# Fetched 100 new records, Total fetched: 4700
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 4700
# Fetched 100 new records, Total fetched: 4800
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 4800
# Fetched 100 new records, Total fetched: 4900
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 4900
# Fetched 100 new records, Total fetched: 5000
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 5000
# Fetched 100 new records, Total fetched: 5100
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 5100
# Fetched 100 new records, Total fetched: 5200
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 5200
# Fetched 100 new records, Total fetched: 5300
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 5300
# Fetched 100 new records, Total fetched: 5400
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 5400
# Fetched 100 new records, Total fetched: 5500
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 5500
# Fetched 34 new records, Total fetched: 5534
# Exiting loop, fetched less than 100 records.
# Fetched 5534 records for Attendance.
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 0
# Fetched 100 new records, Total fetched: 100
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 100
# Fetched 100 new records, Total fetched: 200
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 200
# Fetched 100 new records, Total fetched: 300
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 300
# Fetched 100 new records, Total fetched: 400
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 400
# Fetched 100 new records, Total fetched: 500
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 500
# Fetched 100 new records, Total fetched: 600
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 600
# Fetched 100 new records, Total fetched: 700
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 700
# Fetched 100 new records, Total fetched: 800
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 800
# Fetched 19 new records, Total fetched: 819
# Exiting loop, fetched less than 100 records.
# Fetched 819 records for Student.
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 0
# Fetched 100 new records, Total fetched: 100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 100
# Fetched 100 new records, Total fetched: 200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 200
# Fetched 100 new records, Total fetched: 300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 300
# Fetched 100 new records, Total fetched: 400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 400
# Fetched 100 new records, Total fetched: 500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 500
# Fetched 100 new records, Total fetched: 600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 600
# Fetched 100 new records, Total fetched: 700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 700
# Fetched 100 new records, Total fetched: 800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 800
# Fetched 100 new records, Total fetched: 900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 900
# Fetched 100 new records, Total fetched: 1000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1000
# Fetched 100 new records, Total fetched: 1100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1100
# Fetched 100 new records, Total fetched: 1200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1200
# Fetched 100 new records, Total fetched: 1300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1300
# Fetched 100 new records, Total fetched: 1400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1400
# Fetched 100 new records, Total fetched: 1500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1500
# Fetched 100 new records, Total fetched: 1600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1600
# Fetched 100 new records, Total fetched: 1700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1700
# Fetched 100 new records, Total fetched: 1800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1800
# Fetched 100 new records, Total fetched: 1900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1900
# Fetched 100 new records, Total fetched: 2000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2000
# Fetched 100 new records, Total fetched: 2100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2100
# Fetched 100 new records, Total fetched: 2200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2200
# Fetched 100 new records, Total fetched: 2300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2300
# Fetched 100 new records, Total fetched: 2400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2400
# Fetched 100 new records, Total fetched: 2500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2500
# Fetched 100 new records, Total fetched: 2600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2600
# Fetched 100 new records, Total fetched: 2700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2700
# Fetched 100 new records, Total fetched: 2800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2800
# Fetched 17 new records, Total fetched: 2817
# Exiting loop, fetched less than 100 records.
# Fetched 2817 records for Engagement.
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 0
# Fetched 100 new records, Total fetched: 100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 100
# Fetched 100 new records, Total fetched: 200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 200
# Fetched 100 new records, Total fetched: 300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 300
# Fetched 100 new records, Total fetched: 400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 400
# Fetched 100 new records, Total fetched: 500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 500
# Fetched 100 new records, Total fetched: 600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 600
# Fetched 100 new records, Total fetched: 700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 700
# Fetched 100 new records, Total fetched: 800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 800
# Fetched 100 new records, Total fetched: 900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 900
# Fetched 100 new records, Total fetched: 1000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1000
# Fetched 100 new records, Total fetched: 1100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1100
# Fetched 100 new records, Total fetched: 1200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1200
# Fetched 100 new records, Total fetched: 1300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1300
# Fetched 100 new records, Total fetched: 1400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1400
# Fetched 100 new records, Total fetched: 1500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1500
# Fetched 100 new records, Total fetched: 1600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1600
# Fetched 100 new records, Total fetched: 1700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1700
# Fetched 100 new records, Total fetched: 1800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1800
# Fetched 100 new records, Total fetched: 1900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1900
# Fetched 100 new records, Total fetched: 2000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2000
# Fetched 32 new records, Total fetched: 2032
# Exiting loop, fetched less than 100 records.
# Fetched 2032 records for Engagement.
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 0
# Fetched 100 new records, Total fetched: 100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 100
# Fetched 100 new records, Total fetched: 200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 200
# Fetched 100 new records, Total fetched: 300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 300
# Fetched 100 new records, Total fetched: 400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 400
# Fetched 100 new records, Total fetched: 500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 500
# Fetched 100 new records, Total fetched: 600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 600
# Fetched 100 new records, Total fetched: 700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 700
# Fetched 100 new records, Total fetched: 800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 800
# Fetched 100 new records, Total fetched: 900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 900
# Fetched 100 new records, Total fetched: 1000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1000
# Fetched 100 new records, Total fetched: 1100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1100
# Fetched 100 new records, Total fetched: 1200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1200
# Fetched 100 new records, Total fetched: 1300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1300
# Fetched 100 new records, Total fetched: 1400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1400
# Fetched 100 new records, Total fetched: 1500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1500
# Fetched 100 new records, Total fetched: 1600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1600
# Fetched 100 new records, Total fetched: 1700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1700
# Fetched 100 new records, Total fetched: 1800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1800
# Fetched 100 new records, Total fetched: 1900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1900
# Fetched 100 new records, Total fetched: 2000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2000
# Fetched 100 new records, Total fetched: 2100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2100
# Fetched 100 new records, Total fetched: 2200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2200
# Fetched 100 new records, Total fetched: 2300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2300
# Fetched 100 new records, Total fetched: 2400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2400
# Fetched 100 new records, Total fetched: 2500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2500
# Fetched 100 new records, Total fetched: 2600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2600
# Fetched 100 new records, Total fetched: 2700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2700
# Fetched 100 new records, Total fetched: 2800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2800
# Fetched 100 new records, Total fetched: 2900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2900
# Fetched 100 new records, Total fetched: 3000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3000
# Fetched 100 new records, Total fetched: 3100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3100
# Fetched 100 new records, Total fetched: 3200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3200
# Fetched 100 new records, Total fetched: 3300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3300
# Fetched 100 new records, Total fetched: 3400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3400
# Fetched 100 new records, Total fetched: 3500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3500
# Fetched 100 new records, Total fetched: 3600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3600
# Fetched 100 new records, Total fetched: 3700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3700
# Fetched 100 new records, Total fetched: 3800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3800
# Fetched 100 new records, Total fetched: 3900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3900
# Fetched 100 new records, Total fetched: 4000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4000
# Fetched 29 new records, Total fetched: 4029
# Exiting loop, fetched less than 100 records.
# Fetched 4029 records for Engagement.
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 0
# Fetched 100 new records, Total fetched: 100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 100
# Fetched 100 new records, Total fetched: 200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 200
# Fetched 100 new records, Total fetched: 300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 300
# Fetched 100 new records, Total fetched: 400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 400
# Fetched 100 new records, Total fetched: 500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 500
# Fetched 100 new records, Total fetched: 600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 600
# Fetched 100 new records, Total fetched: 700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 700
# Fetched 100 new records, Total fetched: 800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 800
# Fetched 100 new records, Total fetched: 900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 900
# Fetched 100 new records, Total fetched: 1000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1000
# Fetched 100 new records, Total fetched: 1100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1100
# Fetched 100 new records, Total fetched: 1200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1200
# Fetched 100 new records, Total fetched: 1300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1300
# Fetched 100 new records, Total fetched: 1400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1400
# Fetched 100 new records, Total fetched: 1500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1500
# Fetched 100 new records, Total fetched: 1600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1600
# Fetched 100 new records, Total fetched: 1700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1700
# Fetched 100 new records, Total fetched: 1800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1800
# Fetched 100 new records, Total fetched: 1900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1900
# Fetched 100 new records, Total fetched: 2000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2000
# Fetched 100 new records, Total fetched: 2100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2100
# Fetched 100 new records, Total fetched: 2200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2200
# Fetched 100 new records, Total fetched: 2300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2300
# Fetched 100 new records, Total fetched: 2400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2400
# Fetched 100 new records, Total fetched: 2500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2500
# Fetched 100 new records, Total fetched: 2600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2600
# Fetched 100 new records, Total fetched: 2700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2700
# Fetched 100 new records, Total fetched: 2800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2800
# Fetched 100 new records, Total fetched: 2900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2900
# Fetched 100 new records, Total fetched: 3000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3000
# Fetched 100 new records, Total fetched: 3100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3100
# Fetched 100 new records, Total fetched: 3200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3200
# Fetched 100 new records, Total fetched: 3300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3300
# Fetched 100 new records, Total fetched: 3400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3400
# Fetched 100 new records, Total fetched: 3500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3500
# Fetched 100 new records, Total fetched: 3600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3600
# Fetched 100 new records, Total fetched: 3700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3700
# Fetched 100 new records, Total fetched: 3800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3800
# Fetched 100 new records, Total fetched: 3900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3900
# Fetched 100 new records, Total fetched: 4000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4000
# Fetched 100 new records, Total fetched: 4100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4100
# Fetched 100 new records, Total fetched: 4200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4200
# Fetched 100 new records, Total fetched: 4300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4300
# Fetched 100 new records, Total fetched: 4400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4400
# Fetched 100 new records, Total fetched: 4500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4500
# Fetched 100 new records, Total fetched: 4600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4600
# Fetched 100 new records, Total fetched: 4700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4700
# Fetched 100 new records, Total fetched: 4800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4800
# Fetched 100 new records, Total fetched: 4900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4900
# Fetched 100 new records, Total fetched: 5000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5000
# Fetched 100 new records, Total fetched: 5100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5100
# Fetched 100 new records, Total fetched: 5200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5200
# Fetched 100 new records, Total fetched: 5300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5300
# Fetched 100 new records, Total fetched: 5400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5400
# Fetched 100 new records, Total fetched: 5500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5500
# Fetched 100 new records, Total fetched: 5600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5600
# Fetched 100 new records, Total fetched: 5700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5700
# Fetched 100 new records, Total fetched: 5800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5800
# Fetched 100 new records, Total fetched: 5900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5900
# Fetched 100 new records, Total fetched: 6000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 6000
# Fetched 100 new records, Total fetched: 6100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 6100
# Fetched 100 new records, Total fetched: 6200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 6200
# Fetched 100 new records, Total fetched: 6300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 6300
# Fetched 100 new records, Total fetched: 6400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 6400
# Fetched 100 new records, Total fetched: 6500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 6500
# Fetched 41 new records, Total fetched: 6541
# Exiting loop, fetched less than 100 records.
# Fetched 6541 records for Engagement.
# Processing admissions group: KAM 2K224201
# 1900-01-01 00:00:00
# Processing admissions group: Colleen 2K22NOV1848
# 2024-01-17
# Processing admissions group: Charmaine 2K21JUL2090
# 2023-09-23
# Processing admissions group: CHINAZVO 2K22NOV0980
# 2024-01-17
# Processing admissions group: Davison 2K22SEP1428
# 2024-01-20
# Processing admissions group: Prince 2K21DEC2039
# 2023-09-23
# Processing admissions group: Hove 2K23MAR2348
# 2024-01-20
# Processing admissions group: John 2K21DEC0608
# 1900-01-01 00:00:00
# Processing admissions group: Jonathan 2K23JUN1495
# 2024-01-17
# Processing admissions group: Kimberly 2K22DEC1492
# 2024-01-17
# Processing admissions group: KUDAKWASHE 2K23FEB1701
# 2024-01-20
# Processing admissions group: AUSTIN 2K21SEP0418
# 1900-01-01 00:00:00
# Processing admissions group: Kudziwaishe 2K22NOV0590
# 2024-01-20
# Processing admissions group: Linda 2K23JAN2363
# 2024-01-20
# Processing admissions group: Carren 2K21NOV1275
# 2023-08-26
# Processing admissions group: Miriam 2K22MAY1702
# 2024-01-20
# Processing admissions group: Tafadzwa 2K23JAN2336
# 2024-01-20
# Processing admissions group: Moreblessing 2K22AUG1328
# 2024-01-17
# Processing admissions group: Patron 2K21JUN0812
# 2023-08-19
# Processing admissions group: Precious 2K22AUG2211
# 2024-01-20
# Processing admissions group: Cleopatra 2K23JAN2354
# 2024-01-20
# Processing admissions group: Redeem 2K22SEP1909
# 2024-01-20
# Processing admissions group: Shammah 2K23JAN2795
# 2024-01-20
# Processing admissions group: Shyne 2k21OCT0950
# 2024-01-20
# Processing admissions group: Talent 2K22APR1238
# 2024-01-17
# Processing admissions group: Thubelihle 2K23FEB1715
# 2024-01-20
# Processing admissions group: Tinevimbo 2K21DEC1757
# 1900-01-01 00:00:00
# Processing admissions group: Tino 2K22OCT2525
# 2024-01-20
# Processing admissions group: Tracy 2K22FEB1632
# 2024-01-20
# Processing admissions group: Vincient 2K23JAN2402
# 2024-01-20
# Processing admissions group: Allan 2K23JUL1010
# 2024-01-20
# Processing admissions group: Anesuishe 2K22DEC0852
# 2024-01-20
# Processing admissions group: Antony 2K21DEC0111
# 2023-12-13
# Processing admissions group: Arthur 2K22MAR1907
# 2023-12-13
# Processing admissions group: Audrey 2K22JAN1990
# 2024-01-03
# Processing admissions group: Aznar 2K21APR2744
# 1900-01-01 00:00:00
# Processing admissions group: Bervely 2K23FEB2310
# 2024-01-20
# Processing admissions group: Blessed 2K22JUN0125
# 1900-01-01 00:00:00
# Processing admissions group: Brian 2k21JUN0218
# 1900-01-01 00:00:00
# Processing admissions group: Bright 2K22NOV1526
# 2024-01-03
# Processing admissions group: BRYN 2K23JAN0528
# 2023-12-13
# Processing admissions group: Caleb 2K22NOV1272
# 2023-12-13
# Processing admissions group: Candis 2K22NOV2392
# 2024-01-20
# Processing admissions group: Sheunesu 2K22JAN2012
# 1900-01-01 00:00:00
# Processing admissions group: Meghan 2K22MAR0923
# 1900-01-01 00:00:00
# Processing admissions group: Covenant 2K23MAY1841
# 2024-01-03
# Processing admissions group: Daniel 2K21SEP0775
# 1900-01-01 00:00:00
# Processing admissions group: Danzel 2K22DEC2714
# 2023-12-13
# Processing admissions group: Billy 2K21JUN1680
# 1900-01-01 00:00:00
# Processing admissions group: Elina 2K23JAN1702
# 2023-12-13
# Processing admissions group: Emelia 2K23JAN2432
# 2024-01-03
# Processing admissions group: Eric 2K22MAR1927
# 1900-01-01 00:00:00
# Processing admissions group: Esnaty 2K23JAN1438
# 2023-12-13
# Processing admissions group: Fanwell 2K22NOV1427
# 2024-01-20
# Processing admissions group: Felix 2K22NOV2805
# 2024-01-03
# Processing admissions group: Natasha 2K22DEC1908
# 2024-01-20
# Processing admissions group: Asher 2K23APR2547
# 2024-01-20
# Processing admissions group: Holiness 2K22FEB1130
# 1900-01-01 00:00:00
# Processing admissions group: Joe 2K23JAN1402
# 2024-01-20
# Processing admissions group: Joel 2K21DEC1167
# 1900-01-01 00:00:00
# Processing admissions group: Joseph 2K23JAN1602
# 2024-01-03
# Processing admissions group: Keith 2K22MAY0248
# 1900-01-01 00:00:00
# Processing admissions group: Kudzaiishe 2K23JAN1805
# 2024-01-20
# Processing admissions group: Kuzivakwashe 2K23FEB1895
# 2023-12-13
# Processing admissions group: LISFORD 2K22DEC1308
# 2024-01-20
# Processing admissions group: Lorraine 2K23JAN0518
# 2024-01-20
# Processing admissions group: Maggie 2K21APR2662
# 1900-01-01 00:00:00
# Processing admissions group: Abigail 2K22DEC2057
# 2024-01-20
# Processing admissions group: Makanaka 2K23MAY1103
# 2024-01-03
# Processing admissions group: Makanakaishe 2K21MAR2256
# 1900-01-01 00:00:00
# Processing admissions group: Kudzanai 2K21APR2637
# 1900-01-01 00:00:00
# Processing admissions group: Nicole 2K22FEB1010
# 1900-01-01 00:00:00
# Processing admissions group: Vimbayi 2K22OCT1490
# 2024-01-03
# Processing admissions group: Panashe 2K21JUL1642
# 1900-01-01 00:00:00
# Processing admissions group: Martin 2K21JUL1410
# 1900-01-01 00:00:00
# Processing admissions group: Mary 2K21MAY1750
# 1900-01-01 00:00:00
# Processing admissions group: MASIKA 2K21SEP0430
# 1900-01-01 00:00:00
# Processing admissions group: Miriam 2K22FEB0209
# 2023-09-02
# Processing admissions group: Kelly 2K21MAR1946
# 2024-01-20
# Processing admissions group: Melisa 2K21MAY3162
# 1900-01-01 00:00:00
# Processing admissions group: Michael 2K22MAR0392
# 2023-12-13
# Processing admissions group: Mishael 2K23JUL2191R
# 2024-01-20
# Processing admissions group: Tavanashe 2K23JUN0959
# 2023-12-13
# Processing admissions group: Sandra 2K22AUG1904
# 2024-01-20
# Processing admissions group: Munyaradzi 2K21NOV2274
# 2023-12-13
# Processing admissions group: Ngonidzashe 2K22FEB0120
# 1900-01-01 00:00:00
# Processing admissions group: Tatenda 2K21MAY0740
# 1900-01-01 00:00:00
# Processing admissions group: Natasha 2K22DEC2336
# 2024-01-03
# Processing admissions group: Mayibongwe 2K22OCT0353
# 2023-11-15
# Processing admissions group: Kelly 2K22FEB1801
# 2023-12-16
# Processing admissions group: Nicolene 2K19DEC0701
# 1900-01-01 00:00:00
# Processing admissions group: Nkosinothando 2K21OCT2175
# 1900-01-01 00:00:00
# Processing admissions group: NYARADZO 2K21AUG2703
# 1900-01-01 00:00:00
# Processing admissions group: Nyasha 2K22AUG2601
# 2024-01-03
# Processing admissions group: Panashe 2K23JUN0795
# 2024-01-20
# Processing admissions group: Panashe 2K22JUN3006
# 1900-01-01 00:00:00
# Processing admissions group: Panashe 2K22MAR1786
# 2024-01-20
# Processing admissions group: Patience 2K21DEC3080
# 1900-01-01 00:00:00
# Processing admissions group: Proud 2K22MAY2350
# 1900-01-01 00:00:00
# Processing admissions group: Tatenda 2K22DEC1391
# 2024-01-20
# Processing admissions group: Prosper 2K22JAN1517
# 1900-01-01 00:00:00
# Processing admissions group: Rachael 2K21AUG0913
# 2023-12-13
# Processing admissions group: Ratidzai 2K21MAY1779
# 1900-01-01 00:00:00
# Processing admissions group: Raymond 2K23FEB1710
# 2024-01-20
# Processing admissions group: Ropafadzo 2K23MAY1310
# 2024-01-20
# Processing admissions group: Rutendo 2K22DEC2309
# 2024-01-03
# Processing admissions group: Salma 2K22APR2555
# 1900-01-01 00:00:00
# Processing admissions group: Shanice 2K21APR2123
# 1900-01-01 00:00:00
# Processing admissions group: SHANTEL 2K22AUG0327
# 2024-01-20
# Processing admissions group: Sharon 2K21APR0688
# 1900-01-01 00:00:00
# Processing admissions group: Shumirai 2K21AUG1008
# 1900-01-01 00:00:00
# Processing admissions group: Sikholiwe 2K22JUN1137
# 1900-01-01 00:00:00
# Processing admissions group: Arnold 2K22DEC1502
# 2024-01-03
# Processing admissions group: Sisasenkosi 2K21JUL0651
# 1900-01-01 00:00:00
# Processing admissions group: Tadiwa 2K21AUG2650
# 1900-01-01 00:00:00
# Processing admissions group: Takudzwanashe 2K22DEC0802
# 2024-01-20
# Processing admissions group: Tanaka 2K20OCT0968
# 1900-01-01 00:00:00
# Processing admissions group: Tatenda 2K23JAN1035
# 2024-01-20
# Processing admissions group: THANDIWE 2K23JAN1852
# 2024-01-20
# Processing admissions group: Thubalami 2K22DEC1256
# 2023-12-13
# Processing admissions group: Tinashe 2K22NOV2395
# 2023-12-13
# Processing admissions group: Tinaye 2K21SEP0890
# 1900-01-01 00:00:00
# Processing admissions group: Tricia 2K22APR0918
# 1900-01-01 00:00:00
# Processing admissions group: Twazanga 2K22DEC2093
# 2023-12-13
# Processing admissions group: Utloile 2K23JAN1193
# 2024-01-03
# Processing admissions group: Vanessa 2K22AUG1319
# 2024-01-03
# Processing admissions group: Vincent 2K21AUG1735
# 1900-01-01 00:00:00
# Processing admissions group: Yananai 2K22MAY1707
# 1900-01-01 00:00:00
# Processing admissions group: Abisai 2K22DEC1224
# 2024-01-20
# Processing admissions group: Abigail 2K23JAN1939
# 2024-01-03
# Processing admissions group: Abigail 2K21NOV1559
# 2023-10-07
# Processing admissions group: Adella 2K22FEB2869
# 2023-12-16
# Processing admissions group: Alvin 2K20SEP1918
# 1900-01-01 00:00:00
# Processing admissions group: Anesu 2K22JUL2876
# 1900-01-01 00:00:00
# Processing admissions group: Anesuishe 2K23JAN0525
# 2023-12-16
# Processing admissions group: Ashleigh 2K20AUG2357
# 1900-01-01 00:00:00
# Processing admissions group: Austin 2K23JAN2592
# 2024-01-03
# Processing admissions group: Ayanda 2K22JAN1311
# 1900-01-01 00:00:00
# Processing admissions group: Banenkosi 2K21JAN1519
# 1900-01-01 00:00:00
# Processing admissions group: Blessing 2K22NOV0123
# 2024-01-03
# Processing admissions group: Brita 2K22FEB0232
# 1900-01-01 00:00:00
# Processing admissions group: Calvin 2K21OCT2010
# 1900-01-01 00:00:00
# Processing admissions group: Catherine 2K21JAN0544
# 1900-01-01 00:00:00
# Processing admissions group: Charmaine 2K22AUG2234
# 2024-01-03
# Processing admissions group: Chiedza 2K22FEB1213
# 2023-12-16
# Processing admissions group: Comedy 2K22MAR0380
# 1900-01-01 00:00:00
# Processing admissions group: Courage 2K23MAY0552
# 2024-01-03
# Processing admissions group: Creed 2K22DEC0825
# 2024-01-03
# Processing admissions group: Delight 2K22AUG1266
# 2024-01-03
# Processing admissions group: Desire 2K22SEP0347
# 2024-01-03
# Processing admissions group: Edwin 2K22OCT2589
# 2024-01-03
# Processing admissions group: Rutendo 2K20SEP0717
# 1900-01-01 00:00:00
# Processing admissions group: Fungai 2K22SEP0923
# 2024-01-03
# Processing admissions group: Gerald 2K23JAN1616
# 2024-01-03
# Processing admissions group: Ashley 2K23FEB0130
# 2023-12-16
# Processing admissions group: Hazel 2K22JAN1301
# 1900-01-01 00:00:00
# Processing admissions group: Tinotenda 2K21DEC2032
# 1900-01-01 00:00:00
# Processing admissions group: Nkosilomusa 2K22FEB1940
# 2024-01-03
# Processing admissions group: Jeston 2K22SEP0107
# 2024-01-03
# Processing admissions group: John 2K22AUG0468
# 2024-01-03
# Processing admissions group: Josh 2K22FEB1429
# 1900-01-01 00:00:00
# Processing admissions group: Katelyn 2K22AUG1307
# 2024-01-03
# Processing admissions group: Katendi 2K23FEB1022
# 2024-01-03
# Processing admissions group: Keith 2K23MAR3130R
# 2024-01-03
# Processing admissions group: Kelly 2K23APR1564
# 2024-01-03
# Processing admissions group: Kester 2K22JUL1415
# 2023-12-16
# Processing admissions group: Kudakwashe 2K21JAN1549
# 1900-01-01 00:00:00
# Processing admissions group: Kudzaishe 2K21OCT0502
# 1900-01-01 00:00:00
# Processing admissions group: Leona 2K23MAR2929
# 2024-01-03
# Processing admissions group: LINDA 2K21SEP2213
# 1900-01-01 00:00:00
# Processing admissions group: Lorraine 2K21OCT2331
# 2024-01-03
# Processing admissions group: Lorraine 2K23APR2606
# 2023-12-16
# Processing admissions group: Lorraine 2K22MAY2717
# 2024-01-03
# Processing admissions group: Lynette 2K22AUG2966
# 2024-01-03
# Processing admissions group: Nicole 2K22FEB0526
# 1900-01-01 00:00:00
# Processing admissions group: Mafara 2K21OCT2106
# 1900-01-01 00:00:00
# Processing admissions group: Morefaith 2K22APR2640
# 1900-01-01 00:00:00
# Processing admissions group: Marlene 2K21NOV0268
# 1900-01-01 00:00:00
# Processing admissions group: Patience 2K22SEP2008R
# 2024-01-03
# Processing admissions group: Tatenda 2K22JUN1450
# 2024-01-03
# Processing admissions group: Mellisa 2K22MAR2105
# 1900-01-01 00:00:00
# Processing admissions group: Michell 2K22MAY1924
# 1900-01-01 00:00:00
# Processing admissions group: Mitchelle 2K22NOV2312
# 2024-01-03
# Processing admissions group: Moreblessing 2K22NOV2358
# 2023-12-16
# Processing admissions group: Gilselda 2K21SEP0143
# 1900-01-01 00:00:00
# Processing admissions group: Tariro 2K23JAN0203
# 2024-01-03
# Processing admissions group: Takudzwa 2K22MAR0136R
# 1900-01-01 00:00:00
# Processing admissions group: Melanie 2K23FEB0409
# 2023-12-16
# Processing admissions group: Natalie 2K22SEP2234
# 2024-01-03
# Processing admissions group: Nathaniel 2K23MAR1548
# 2024-01-03
# Processing admissions group: Nicassio 2K22JUL2945
# 2024-01-03
# Processing admissions group: Nigel 2K23APR0768
# 2023-12-16
# Processing admissions group: Nokutenda 2K23APR1822
# 2024-01-03
# Processing admissions group: Nozizwe 2K23FEB2111R
# 2024-01-03
# Processing admissions group: Nqobizitha 2K20NOV3032
# 1900-01-01 00:00:00
# Processing admissions group: Emmanuel 2K22JAN1094
# 1900-01-01 00:00:00
# Processing admissions group: Nyasha 2K23APR0412
# 2024-01-03
# Processing admissions group: Nyasha 2K22FEB0350
# 1900-01-01 00:00:00
# Processing admissions group: Nyashadzashe 2K23MAR0433
# 2024-01-03
# Processing admissions group: Ephinas 2K23MAR0322
# 2023-12-16
# Processing admissions group: Obey 2K22MAY0638
# 1900-01-01 00:00:00
# Processing admissions group: Hakeem 2K20SEP2423
# 1900-01-01 00:00:00
# Processing admissions group: Leanet 2K21JAN0241
# 1900-01-01 00:00:00
# Processing admissions group: Pamella 2K22DEC0848
# 2023-12-16
# Processing admissions group: Panashe 2K21JAN1157
# 1900-01-01 00:00:00
# Processing admissions group: Panashe 2K22MAR2257
# 1900-01-01 00:00:00
# Processing admissions group: Pardon 2K22FEB0703
# 1900-01-01 00:00:00
# Processing admissions group: Patience 2K23MAR2355R
# 2023-12-16
# Processing admissions group: Prisca 2K20DEC032
# 1900-01-01 00:00:00
# Processing admissions group: Progress 2K22NOV1428
# 2024-01-03
# Processing admissions group: Providence 2K21OCT0173
# 1900-01-01 00:00:00
# Processing admissions group: Ropafadzo 2K21JUL0642
# 1900-01-01 00:00:00
# Processing admissions group: Rufaro 2K23JUN1220
# 2023-12-16
# Processing admissions group: RUTH 2K23MAR2137
# 2024-01-03
# Processing admissions group: Ryan 2K23JAN1318
# 2023-12-16
# Processing admissions group: Shalom 2K22APR0802
# 1900-01-01 00:00:00
# Processing admissions group: Shantel 2K23JAN0755
# 2023-12-16
# Processing admissions group: Shawn 2K22NOV0328
# 2023-12-16
# Processing admissions group: Shekinah 2K22MAR0242
# 2024-01-03
# Processing admissions group: Shingai 2K22JUN0909R
# 1900-01-01 00:00:00
# Processing admissions group: Sibongile 2K22AUG2201
# 2023-12-16
# Processing admissions group: Silence 2K23JAN0337
# 2023-12-16
# Processing admissions group: Simphiwe 2K22DEC0692
# 2023-12-16
# Processing admissions group: Tatire 2K21DEC2464
# 2023-12-16
# Processing admissions group: Tadiwa 2K22AUG1645
# 2023-12-16
# Processing admissions group: Tadiwanashe 2K22DEC1367
# 2023-12-16
# Processing admissions group: Tafadzwa 2K22MAR2408
# 1900-01-01 00:00:00
# Processing admissions group: Tafadzwa 2K20AUG2412
# 1900-01-01 00:00:00
# Processing admissions group: Tafadzwa 2K22JUN2952
# 2023-12-16
# Processing admissions group: Takudzwa 2K22OCT1484
# 2023-12-16
# Processing admissions group: Talent 2K22MAY1047
# 1900-01-01 00:00:00
# Processing admissions group: Tanyaradzwa 2K22JUL2532
# 2023-12-16
# Processing admissions group: Tanyaradzwa 2K22NOV3047
# 2023-12-16
# Processing admissions group: Taonga 2K22DEC2048
# 2024-01-27
# Processing admissions group: Courtney 2K23MAR1742
# 2023-12-16
# Processing admissions group: TARIRO 2K22MAR1645
# 2023-12-16
# Processing admissions group: Tatenda 2K21JAN0853
# 1900-01-01 00:00:00
# Processing admissions group: Tecla 2K22FEB0452
# 2023-12-16
# Processing admissions group: Tendai 2K21MAY0750
# 1900-01-01 00:00:00
# Processing admissions group: Thelma 2K23JUL1538
# 2023-12-16
# Processing admissions group: Thomas 2K22JUN2212
# 2024-01-03
# Processing admissions group: Tinevimbo 2K22JUN2488
# 2023-12-16
# Processing admissions group: Tsitsi 2K22NOV1859
# 2023-12-16
# Processing admissions group: Vinah 2K22OCT2821
# 2023-12-16
# Processing admissions group: Wadzanai 2K21AUG2047
# 1900-01-01 00:00:00
# ...
# 1900-01-01 00:00:00
# Processing admissions group: Beverley 2K22APR1912
# 1900-01-01 00:00:00
# Processing admissions group: Natalie 2K22APR1572
# 1900-01-01 00:00:00
# Processing admissions group: Winnstone 2K22APR2126
# 2023-08-26
# Processing admissions group: Mupona 2K22APR2660
# 1900-01-01 00:00:00
# Processing admissions group: Tanyaradzwa 2K22APR2382
# 2024-01-20
# Processing admissions group: Nigel 2K22APR2505
# 1900-01-01 00:00:00
# Processing admissions group: Nigel 2K22APR2652
# 1900-01-01 00:00:00
# Processing admissions group: Tadiwanashe 2K22APR2608
# 1900-01-01 00:00:00
# Processing admissions group: Brighton 2K22APR2626
# 2024-01-10
# Processing admissions group: Shamiso 2K22MAY0572
# 1900-01-01 00:00:00
# Processing admissions group: Tecla 2K22MAY1238
# 1900-01-01 00:00:00
# Processing admissions group: Sean 2K22MAY1953
# 1900-01-01 00:00:00
# Processing admissions group: Welshman 2K22MAY1912
# 1900-01-01 00:00:00
# Processing admissions group: Anesu 2K22JUN1424
# 2024-01-17
# Processing admissions group: Prince 2K22JUL0545
# 1900-01-01 00:00:00
# Processing admissions group: Samantha 2K23MAR0203
# 2024-01-03
# Processing admissions group: Tapiwanashe 2K23MAR0134
# 2024-01-20
# Processing admissions group: Tariro 2K23MAR2342
# 2024-01-06
# Processing admissions group: Abigail 2K23AUG1091R
# 2023-12-16
# Processing admissions group: Kudzwai 2K21OCT0468
# 1900-01-01 00:00:00
# Processing admissions group: Kudakwashe 2K23JUN1089
# 2024-01-20
# Processing admissions group: Shammah 2K21JUL1707
# 1900-01-01 00:00:00
# Processing admissions group: Bernadette 2K22AUG1040
# 2024-01-20
# Processing admissions group: Francesca 2K23AUG1892
# 2024-01-20
# Processing admissions group: Nashville 2K23AUG2266R
# 2024-01-20
# Processing admissions group: Gugulethu 2K23AUG1858
# 2023-12-13
# Processing admissions group: Shingirai 2K23AUG2597
# 2024-01-20
# Processing admissions group: Blessing 2K23FEB2334
# 2024-01-17
# Processing admissions group: Brenda 2K23FEB0992
# 2024-01-17
# Processing admissions group: Ashley 2K22MAR1652
# 1900-01-01 00:00:00
# Processing admissions group: Rutendo 2K22MAR1777
# 2024-01-20
# Processing admissions group: Natashe 2K22MAR1410
# 1900-01-01 00:00:00
# Processing admissions group: Rufaro 2K23FEB0692
# 2024-01-06
# Processing admissions group: Allen 2K22SEP2695
# 2024-01-17
# Processing admissions group: Neo 2K23MAY0223
# 2024-01-03
# Processing admissions group: Wilma 2K21SEP0848
# 2023-12-23
# Processing admissions group: Bhekinkosi 2K22OCT2498
# 2024-01-17
# Processing admissions group: Natasha 2K22JAN1001
# 1900-01-01 00:00:00
# Processing admissions group: Courage 2K22JUL1682
# 2023-12-16
# Processing admissions group: Ruth 2K22DEC1240
# 2024-01-20
# Processing admissions group: Ownwell 2K20AUG2760
# 1900-01-01 00:00:00
# Processing admissions group: Charleen 2K23JAN0501
# 2023-12-16
# Processing admissions group: Michael 2K23FEB0902
# 2024-01-03
# Processing admissions group: Praise 2K22NOV1618
# 2024-01-20
# Processing admissions group: Kelvin 2K23JUN0905
# 2023-12-13
# Processing admissions group: Panashe 2K22JUL2904
# 2024-01-03
# Processing admissions group: Takunda 2K22JUL2006
# 2024-01-18
# Processing admissions group: Zvikomborero 2K22JAN2085
# 2024-01-18
# Processing admissions group: Patience 2K21APR0603
# 1900-01-01 00:00:00
# Processing admissions group: Morgan 2K21AUG1303
# 1900-01-01 00:00:00
# Processing admissions group: Tanatswa 2K22DEC0732
# 2024-01-20
# Processing admissions group: Faith 2K22SEP0382
# 2023-08-26
# Processing admissions group: Evans 2K23JAN2728
# 2023-12-16
# Processing admissions group: Tinotenda 2K22MAY0926
# 2023-12-16
# Processing admissions group: Tatenda 2K22OCT2008
# 2024-01-20
# Processing admissions group: Shelter 2K23JUN1598
# 2024-01-20
# Processing admissions group: Trust 2K21JUN0278
# 1900-01-01 00:00:00
# Processing admissions group: Yananisai 2K22JUN1305
# 1900-01-01 00:00:00
# Processing admissions group: Ruwende 2K21JUL3066
# 1900-01-01 00:00:00
# Processing admissions group: Jason 2K22FEB2185
# 1900-01-01 00:00:00
# Processing admissions group: Rufaro 2K23AUG1598
# 2024-01-30
# Processing admissions group: Sharon 2K21JUL0956
# 1900-01-01 00:00:00
# Processing admissions group: Shalom 2K23JUN1242
# 2024-01-03
# Processing admissions group: Denzel 2K21SEP2533
# 1900-01-01 00:00:00
# Processing admissions group: Fadzai 2K22DEC2804
# 2024-01-03
# Processing admissions group: Caroline 2K21OCT2169
# 2024-01-03
# Processing admissions group: Tinotenda 2K22FEB1238
# 2024-01-17
# Processing admissions group: Patience 2K22JAN2180
# 2024-01-03
# Processing admissions group: Ashleigh 2K22FEB1857
# 1900-01-01 00:00:00
# Processing admissions group: Tafadzwa 2K21DEC2705
# 1900-01-01 00:00:00
# Processing admissions group: Tadiwanashe 2K22JAN1322
# 2024-01-18
# Processing admissions group: Jesca 2K22DEC0725
# 2024-01-20
# Processing admissions group: Sharon 2K22FEB2512
# 1900-01-01 00:00:00
# Processing admissions group: Gerald 2K21JUL2002
# 1900-01-01 00:00:00
# Processing admissions group: Rebecca 2K21AUG0737
# 1900-01-01 00:00:00
# Processing admissions group: Kafula 2K23JUL1095
# 2023-11-09
# Processing admissions group: Natasha 2K22MAY1847
# 1900-01-01 00:00:00
# Processing admissions group: Hazel 2k21Nov1805
# 1900-01-01 00:00:00
# Processing admissions group: Brita 2K22AUG1238
# 2024-01-03
# Processing admissions group: Trinity 2K23MAR0313
# 2024-01-03
# Processing admissions group: Angeline 2K23FEB2804
# 2024-01-06
# Processing admissions group: Nyasha 2K23AUG0735
# 2024-01-17
# Processing admissions group: Bradley 2K22MAR2204
# 1900-01-01 00:00:00
# Processing admissions group: Prince 2K20FEB2506
# 1900-01-01 00:00:00
# Processing admissions group: Tsitsi 2K20AUG2927
# 1900-01-01 00:00:00
# Processing admissions group: LILIAN 2K22MAR1412
# 2024-01-20
# Processing admissions group: Tatenda 2K22FEB1753
# 1900-01-01 00:00:00
# Processing admissions group: Vincent 2K22JUN1007
# 2023-09-23
# Processing admissions group: Takudzwa 2K22AUG1031
# 2023-12-13
# Processing admissions group: Denise 2K21JUN1085
# 1900-01-01 00:00:00
# Processing admissions group: Mudzuri 2K21MAR0521
# 1900-01-01 00:00:00
# Processing admissions group: Tolerant 2K23JUN2995
# 2024-01-20
# Processing admissions group: Emeni 2K22MAY0922
# 1900-01-01 00:00:00
# Processing admissions group: Mercynay 2K23JUN2895
# 2024-01-20
# Processing admissions group: Vanessa 2K21OCT1834
# 1900-01-01 00:00:00
# Processing admissions group: Amani 2K23AUG0305
# 2023-12-13
# Processing admissions group: Blessing 2K21DEC1302
# 1900-01-01 00:00:00
# Processing admissions group: Lionel 2K21MAY2561
# 1900-01-01 00:00:00
# Processing admissions group: Tendekai 2K21AUG2610
# 1900-01-01 00:00:00
# Processing admissions group: Nigel 2K23MAR1324
# 2024-01-12
# Processing admissions group: Emelda 2K22JUN0346
# 2024-01-03
# Processing admissions group: Hazel 2K23FEB1499
# 2024-01-18
# Processing admissions group: Michael 2K22FEB0824
# 1900-01-01 00:00:00
# Processing admissions group: Tiriwashe 2K23JUL2192
# 2024-01-20
# Processing admissions group: Evidence 2K22JUN1714
# 2023-12-02
# Processing admissions group: Tanaka 2K23JAN2309
# 1900-01-01 00:00:00
# Processing admissions group: Joyce 2K22OCT1382
# 2024-01-03
# Processing admissions group: Takudzwa 2K22APR2585
# 1900-01-01 00:00:00
# Processing admissions group: Timukudze 2K22DEC1272
# 2024-01-20
# Processing admissions group: PATIENCE 2K22JUN2218
# 2023-12-16
# Processing admissions group: Felix 2K21DEC0135
# 1900-01-01 00:00:00
# Processing admissions group: Aureen 2K21AUG1853
# 1900-01-01 00:00:00
# Processing admissions group: Sibonginkosi 2K21JAN1117
# 1900-01-01 00:00:00
# Processing admissions group: Takunda 2K21JUN1628
# 1900-01-01 00:00:00
# Processing admissions group: Kudakwashe 2K22JUN2813
# 1900-01-01 00:00:00
# Processing admissions group: Rumbidzai 2K22APR2666
# 1900-01-01 00:00:00
# Processing admissions group: Dylan 2K22JUN1646
# 1900-01-01 00:00:00
# Processing admissions group: Laura 2K23FEB0392
# 2024-01-20
# Processing admissions group: Isaac 2K21JUN2244
# 1900-01-01 00:00:00
# Processing admissions group: Bridget 2K23MAY0564
# 2024-01-06
# Processing admissions group: Sharon 2K20DEC1212
# 1900-01-01 00:00:00
# Processing admissions group: Panashe 2K22JAN2212
# 1900-01-01 00:00:00
# Processing admissions group: Paidamoyo 2K21MAR1236
# 1900-01-01 00:00:00
# Processing admissions group: Wellington 2K22DEC3002
# 2023-12-06
# Processing admissions group: Tendai 2K22AUG2312
# 2024-01-03
# Processing admissions group: James 2K23JAN0228
# 2024-01-03
# Processing admissions group: Nokuthaba 2K22AUG2604
# 2023-12-16
# Processing admissions group: Aletta 2K22OCT0734
# 2024-01-03
# Processing admissions group: Valentine 2K21FEB1545
# 1900-01-01 00:00:00
# Processing admissions group: Theodore 2K23JAN1253
# 2024-01-20
# Processing admissions group: Lenon 2K22JUN2040
# 1900-01-01 00:00:00
# Processing admissions group: Luyanda 2K21OCT1120
# 2024-01-03
# Processing admissions group: Claudett 2K22JUN0216
# 1900-01-01 00:00:00
# Processing admissions group: TAURAI 2K22FEB1878
# 1900-01-01 00:00:00
# Processing admissions group: Tadiwanashe 2K22DEC1355
# 2023-12-16
# Processing admissions group: Humphrey 2K21SEP0180
# 2024-01-03
# Processing admissions group: Caroline 2K22SEP0882
# 2023-12-13
# Processing admissions group: Gamuchirai 2K21NOV1514
# 1900-01-01 00:00:00
# Processing admissions group: Lyona 2K22JAN1236
# 2024-01-06
# Processing admissions group: Keith 2K21JAN1874
# 1900-01-01 00:00:00
# Processing admissions group: Vincent 2K23JAN0995
# 2023-12-16
# Processing admissions group: Phinias 2K21JAN1650
# 1900-01-01 00:00:00
# Processing admissions group: REBECCA 2K23JUN0964
# 2024-01-20
# Processing admissions group: Francine 2K23FEB0203
# 2023-12-16
# Processing admissions group: Comfort 2K21AUG2784
# 1900-01-01 00:00:00
# Processing admissions group: Judith 2K21AUG1856
# 1900-01-01 00:00:00
# Processing admissions group: Anotidaishe 2K23JUL0739
# 2024-01-20
# Processing admissions group: Nirnoy 2K23AUG2208
# 1900-01-01 00:00:00
# Processing admissions group: Takudzwanashe 2K23FEB0892
# 2024-01-06
# Processing admissions group: Alexios 2K22MAY2124
# 1900-01-01 00:00:00
# Processing admissions group: TINOTENDA 2K22JUN0913R
# 1900-01-01 00:00:00
# Processing admissions group: Jubilance 2K22MAR0865
# 1900-01-01 00:00:00
# Processing admissions group: Rachael 2K21SEP0225
# 1900-01-01 00:00:00
# Processing admissions group: ALLAN 2K21SEP0419
# 2023-08-19
# Processing admissions group: Bandile 2K19DEC1768
# 1900-01-01 00:00:00
# Processing admissions group: Joseph EWYLJAN2058
# 1900-01-01 00:00:00
# Processing admissions group: Samuel 2K20MAR1232
# 1900-01-01 00:00:00
# Processing admissions group: Kuda 2K20MAR1902
# 1900-01-01 00:00:00
# Processing admissions group: Lovejoy 2K20JUN1233
# 1900-01-01 00:00:00
# Processing admissions group: Seddiq 2K20JUN1942
# 1900-01-01 00:00:00
# Processing admissions group: Awuni 2K20JUN1727
# 1900-01-01 00:00:00
# Processing admissions group: Philomena 2K20JUL1426
# 1900-01-01 00:00:00
# Processing admissions group: Susan 2K20NOV1301
# 1900-01-01 00:00:00
# Processing admissions group: Trish 2K20NOV2150
# 1900-01-01 00:00:00
# Processing admissions group: James 2K21JAN0520
# 1900-01-01 00:00:00
# Processing admissions group: Malvern 2K21FEB0839
# 1900-01-01 00:00:00
# Processing admissions group: Mthulisi 2K21MAR1512
# 1900-01-01 00:00:00
# Processing admissions group: Unity 2K21APR0509
# 1900-01-01 00:00:00
# Processing admissions group: Theophilus 2K21APR2112
# 1900-01-01 00:00:00
# Processing admissions group: Panashe 2K21JUN1428
# 1900-01-01 00:00:00
# Processing admissions group: Tanaka 2K21JUL0238
# 2024-01-18
# Processing admissions group: Martin 2K21AUG0210
# 1900-01-01 00:00:00
# Processing admissions group: Geoff 2K21SEP0613
# 1900-01-01 00:00:00
# Processing admissions group: Tinashe 2K21SEP2264R
# 1900-01-01 00:00:00
# Processing admissions group: Sandra 2K21OCT0169
# 1900-01-01 00:00:00
# Processing admissions group: Viola 2K21OCT2602
# 1900-01-01 00:00:00
# Processing admissions group: Trudie 2K22JUN1639
# 1900-01-01 00:00:00
# Processing admissions group: Nisar 2K20JAN0607
# 1900-01-01 00:00:00
# Processing admissions group: Kelis 2K20JAN1664
# 1900-01-01 00:00:00
# Processing admissions group: Nicholas 2K20JAN21
# 1900-01-01 00:00:00
# Processing admissions group: Joy EWYLJAN2431
# 1900-01-01 00:00:00
# Processing admissions group: Edmund 2K20JAN3075
# 1900-01-01 00:00:00
# Processing admissions group: Gumede 2K20JAN1669
# 1900-01-01 00:00:00
# Processing admissions group: Frederick EWYLFEB0313
# 1900-01-01 00:00:00
# Processing admissions group: Panashe 2K20FEB1158
# 1900-01-01 00:00:00
# Processing admissions group: Elizabeth 2K20MAR0311
# 1900-01-01 00:00:00
# Processing admissions group: Farooq 2K20MAR1280
# 1900-01-01 00:00:00
# Processing admissions group: Amoako 2K20APR1319
# 1900-01-01 00:00:00
# Processing admissions group: Calton 2K20AUG2611
# 1900-01-01 00:00:00
# Processing admissions group: Disney 2K20AUG3122
# 1900-01-01 00:00:00
# Processing admissions group: Memory 2K20SEP0128
# 1900-01-01 00:00:00
# Processing admissions group: Tadiwanashe 2K20SEP134
# 1900-01-01 00:00:00
# Processing admissions group: Ryan 2K20SEP0101
# 1900-01-01 00:00:00
# Processing admissions group: Munyaradzi 2K20SEP1107
# 1900-01-01 00:00:00
# Processing admissions group: Silence 2K20SEP1649
# 1900-01-01 00:00:00
# Processing admissions group: Wandile 2K20OCT0643
# 1900-01-01 00:00:00
# Processing admissions group: Sandra 2K20OCT0941
# 1900-01-01 00:00:00
# Processing admissions group: Brian 2K20NOV1120
# 1900-01-01 00:00:00
# Processing admissions group: Thrive 2K20DEC1422
# 1900-01-01 00:00:00
# Processing admissions group: Tendai 2K21JAN0827
# 1900-01-01 00:00:00
# Processing admissions group: Zibusiso 2K21FEB0909
# 1900-01-01 00:00:00
# Processing admissions group: Ropafadzo 2K21FEB2050
# 1900-01-01 00:00:00
# Processing admissions group: Cynthia 2K21MAR0258
# 1900-01-01 00:00:00
# Processing admissions group: Rufaro 2K21MAR0577
# 1900-01-01 00:00:00
# Processing admissions group: Arnold 2K21MAR1017
# 1900-01-01 00:00:00
# Processing admissions group: Anesu 2K21MAR2043
# 1900-01-01 00:00:00
# Processing admissions group: Christine 2K21MAR2039
# 1900-01-01 00:00:00
# Processing admissions group: Rumbidzai 2K21MAR2640
# 1900-01-01 00:00:00
# Processing admissions group: Joyleen 2K21APR0268
# 1900-01-01 00:00:00
# Processing admissions group: Gladsome 2K21MAR3101
# 1900-01-01 00:00:00
# Processing admissions group: Wesley 2K21APR1367
# 1900-01-01 00:00:00
# Processing admissions group: Samantha 2K21APR1450
# 1900-01-01 00:00:00
# Processing admissions group: Sibonginkosi 2K21MAY0127
# 1900-01-01 00:00:00
# Processing admissions group: Takudzwa 2K21MAY0404
# 1900-01-01 00:00:00
# Processing admissions group: Tapiwa 2K21APR3027
# 1900-01-01 00:00:00
# Processing admissions group: Shyline 2K21MAY1212
# 1900-01-01 00:00:00
# Processing admissions group: Zanza 2K21MAY1150
# 1900-01-01 00:00:00
# Processing admissions group: Eunick 2K21MAY0716
# 1900-01-01 00:00:00
# Processing admissions group: Sandra 2K21MAY1077
# 1900-01-01 00:00:00
# Processing admissions group: CHIMUSWE 2K21MAY1229
# 1900-01-01 00:00:00
# Processing admissions group: Gavinia 2K21MAY1268
# 1900-01-01 00:00:00
# Processing admissions group: Shepherd 2K21MAY1404
# 1900-01-01 00:00:00
# Processing admissions group: ESNATH 2K21MAY1860
# 1900-01-01 00:00:00
# Processing admissions group: Annatoria 2K21MAY2437
# 1900-01-01 00:00:00
# Processing admissions group: Archival 2K21MAY2523
# 1900-01-01 00:00:00
# Processing admissions group: Sidalubuhle 2K21MAY2402
# 1900-01-01 00:00:00
# Processing admissions group: Sibanda 2K21JUN0345
# 1900-01-01 00:00:00
# Processing admissions group: NYASHA 2K21JUN0976
# 1900-01-01 00:00:00
# Processing admissions group: KUDZAYI 2K21MAY0324
# 1900-01-01 00:00:00
# Processing admissions group: Chiturumani 2K21JUN1967
# 1900-01-01 00:00:00
# Processing admissions group: Nyasha 2K21JUN1814
# 1900-01-01 00:00:00
# Processing admissions group: Tanaka 2K21JUL0283
# 1900-01-01 00:00:00
# Processing admissions group: Varaidzo 2K21JUL0532
# 1900-01-01 00:00:00
# Processing admissions group: Isabel 2K21JUL0657
# 1900-01-01 00:00:00
# Processing admissions group: Takudzwa 2K21JUN2575
# 1900-01-01 00:00:00
# Processing admissions group: Nomzamo 2K21JUL1666
# 1900-01-01 00:00:00
# Processing admissions group: Evans 2K21JUL2210
# 1900-01-01 00:00:00
# Processing admissions group: Abraham 2K21AUG0303
# 1900-01-01 00:00:00
# Processing admissions group: Simbarashe 2K21AUG0923
# 1900-01-01 00:00:00
# Processing admissions group: Anna 2K22APR2085
# 2023-12-16
# Processing admissions group: Tadiwanashe 2K22SEP1715
# 2024-01-18
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []

# %%
import nest_asyncio
nest_asyncio.apply()

import aiohttp
import asyncio
import json
import pandas as pd
from datetime import datetime 
from datetime import timedelta


student_df = None
engagement_df = None
ums_att_df = None
ums_avg_att_df = None
ums_upload_avg_att=None

edoofy_base_url = "https://edoofa-portal.bubbleapps.io/api/1.1/obj"
edoofy_bearer_token = "2cde31d8f48919a2db1467cc06a56132"
edoofy_headers = {'Authorization': f'Bearer {edoofy_bearer_token}'}

ums_base_url = "https://app.edoofa.com/version-test/api/1.1/obj"
ums_bearer_token = "786720e8eb68de7054d1149b56cc04f9"
ums_headers = {'Authorization': f'Bearer {ums_bearer_token}'}


async def fetch_table_data(session, base_url, headers, table, constraints=None):
    records = []
    cursor = 0
    total_fetched = 0

    while True:
        params = {'limit': 100, 'cursor': cursor}
        if constraints:
            params['constraints'] = json.dumps(constraints)

        api_url = f"{base_url}/{table}"
        print(f"Fetching {table} data from {base_url}... Cursor: {cursor}")

        async with session.get(api_url, headers=headers, params=params) as response:
            if response.status != 200:
                print(f"Failed to fetch data from {table}: {await response.text()}")
                break

            data = await response.json()
            new_records = data['response']['results']
            records.extend(new_records)
            total_fetched += len(new_records)

            print(f"Fetched {len(new_records)} new records, Total fetched: {total_fetched}")

            cursor += 100

            if len(new_records) < 100:
                print(f"Exiting loop, fetched less than 100 records.")
                break

    df = pd.DataFrame(records)
    print(f"Fetched {len(df)} records for {table}.")
    return df



def create_attendance_row(engagement_record):
    attendance_row = {
        'admissions-group-name': engagement_record['admissions-group-name'],  
        'attendance-type': engagement_record['engagement-type'],  
        'date': engagement_record['adjusted-engagement-date'],  
        'ewyl-group-name': engagement_record['ewyl-group-name'],  
        'present': engagement_record['daily-attendance'],  
    }

    return attendance_row

async def post_attendance_record(session, url, headers, record):
    try:
        async with session.post(url, headers=headers, json=record) as response:
            if response.status == 200:
                print("Record posted successfully.")
                return await response.json()
            else:
                print(f"Failed to post record: {await response.text()}")
                return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None


async def main():
    async with aiohttp.ClientSession() as session:
        ums_student_df = await fetch_table_data(session, ums_base_url, ums_headers, "Student")
        ums_att_df = await fetch_table_data(session, ums_base_url, ums_headers, "Attendance")  
        student_constraints = [{'key': 'indian-edoofian', 'constraint_type': 'equals', 'value': 'yes'}]
        student_df = await fetch_table_data(session, edoofy_base_url, edoofy_headers, "Student", constraints=student_constraints)
        
        engagement_df = pd.DataFrame()
        for engagement_type in ['IE Call', 'IE Chat', 'Activity', 'Lesson']:
            engagement_data = await fetch_table_data(session, edoofy_base_url, edoofy_headers, "Engagement", [{'key': 'engagement-type', 'constraint_type': 'equals', 'value': engagement_type}])
            engagement_df = pd.concat([engagement_df, engagement_data], ignore_index=True)
        
        engagement_df = pd.merge(engagement_df, student_df[['_id', 'KAM-group-name', 'EWYL-group-name']], left_on='student', right_on='_id', how='left')
        engagement_df.rename(columns={'KAM-group-name': 'admissions-group-name', 'EWYL-group-name': 'ewyl-group-name', '_id_x': '_id'}, inplace=True)
        engagement_df.drop(['_id_y'], axis=1, inplace=True)
        engagement_df.dropna(subset=['admissions-group-name'], inplace=True)
        
        # Convert dates to datetime objects for accurate comparisons
        ums_att_df['date'] = pd.to_datetime(ums_att_df['date']).dt.tz_localize(None)
        engagement_df['engagement-date'] = pd.to_datetime(engagement_df['engagement-date']).dt.tz_localize(None)

        engagement_df['adjusted-engagement-date'] = pd.to_datetime(engagement_df['engagement-date']) + timedelta(hours=5, minutes=30)
        engagement_df.to_csv("engagement_df.csv", index=False)
        new_attendance_records = []

        for _, student in student_df.iterrows():
            admissions_group_name = student['KAM-group-name']
            print(f"Processing admissions group: {admissions_group_name}")

            # Get the latest engagement date for the current student
            latest_engagement_date = engagement_df[engagement_df['admissions-group-name'] == admissions_group_name]['adjusted-engagement-date'].max()

            # Get the latest UMS attendance date for the current student
            latest_ums_attendance_date = ums_att_df[ums_att_df['admissions-group-name'] == admissions_group_name]['date'].max()

            # Process only if the latest engagement date is after the latest UMS attendance date
            if pd.isnull(latest_engagement_date) or pd.isnull(latest_ums_attendance_date) or latest_engagement_date <= latest_ums_attendance_date:
                # Skip this student if there's no latest engagement date or the latest engagement date is not after the latest UMS attendance date
                continue

            # Filter engagements that occurred after the latest UMS attendance date
            engagements_to_process = engagement_df[(engagement_df['admissions-group-name'] == admissions_group_name) & 
                                                   (engagement_df['adjusted-engagement-date'] > latest_ums_attendance_date)]

            # Process each relevant engagement
            for _, engagement in engagements_to_process.iterrows():
                new_row = create_attendance_row(engagement)
                new_attendance_records.append(new_row)

        # Convert the list of new rows to a DataFrame
        new_attendance_df = pd.DataFrame(new_attendance_records)

        """
        # Post new attendance records if any
        if not new_attendance_df.empty:
            new_attendance_df['date'] = new_attendance_df['date'].dt.strftime('%m/%d/%Y') + " 05:30 AM"
            for _, record in new_attendance_df.iterrows():
                admissions_group_name = record['admissions-group-name']
                print(f"Posting attendance for admissions group: {admissions_group_name}")
                url = f"{ums_base_url}/Attendance"
                await post_attendance_record(session, url, ums_headers, record.to_dict())
        else:
            print("No new attendance records to process.")
        """
        
        print(new_attendance_df.head())
        return new_attendance_df
        new_attendance_df.to_csv("new_attendance_df.csv", index= False)

await main()
# Out:
# Fetching Student data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 0
# Fetched 100 new records, Total fetched: 100
# Fetching Student data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 100
# Fetched 100 new records, Total fetched: 200
# Fetching Student data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 200
# Fetched 100 new records, Total fetched: 300
# Fetching Student data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 300
# Fetched 100 new records, Total fetched: 400
# Fetching Student data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 400
# Fetched 100 new records, Total fetched: 500
# Fetching Student data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 500
# Fetched 100 new records, Total fetched: 600
# Fetching Student data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 600
# Fetched 100 new records, Total fetched: 700
# Fetching Student data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 700
# Fetched 100 new records, Total fetched: 800
# Fetching Student data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 800
# Fetched 20 new records, Total fetched: 820
# Exiting loop, fetched less than 100 records.
# Fetched 820 records for Student.
# Fetching Attendance data from https://app.edoofa.com/version-test/api/1.1/obj... Cursor: 0
# Fetched 1 new records, Total fetched: 1
# Exiting loop, fetched less than 100 records.
# Fetched 1 records for Attendance.
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 0
# Fetched 100 new records, Total fetched: 100
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 100
# Fetched 100 new records, Total fetched: 200
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 200
# Fetched 100 new records, Total fetched: 300
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 300
# Fetched 100 new records, Total fetched: 400
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 400
# Fetched 100 new records, Total fetched: 500
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 500
# Fetched 100 new records, Total fetched: 600
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 600
# Fetched 100 new records, Total fetched: 700
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 700
# Fetched 100 new records, Total fetched: 800
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 800
# Fetched 19 new records, Total fetched: 819
# Exiting loop, fetched less than 100 records.
# Fetched 819 records for Student.
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 0
# Fetched 100 new records, Total fetched: 100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 100
# Fetched 100 new records, Total fetched: 200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 200
# Fetched 100 new records, Total fetched: 300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 300
# Fetched 100 new records, Total fetched: 400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 400
# Fetched 100 new records, Total fetched: 500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 500
# Fetched 100 new records, Total fetched: 600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 600
# Fetched 100 new records, Total fetched: 700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 700
# Fetched 100 new records, Total fetched: 800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 800
# Fetched 100 new records, Total fetched: 900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 900
# Fetched 100 new records, Total fetched: 1000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1000
# Fetched 100 new records, Total fetched: 1100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1100
# Fetched 100 new records, Total fetched: 1200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1200
# Fetched 100 new records, Total fetched: 1300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1300
# Fetched 100 new records, Total fetched: 1400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1400
# Fetched 100 new records, Total fetched: 1500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1500
# Fetched 100 new records, Total fetched: 1600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1600
# Fetched 100 new records, Total fetched: 1700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1700
# Fetched 100 new records, Total fetched: 1800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1800
# Fetched 100 new records, Total fetched: 1900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1900
# Fetched 100 new records, Total fetched: 2000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2000
# Fetched 100 new records, Total fetched: 2100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2100
# Fetched 100 new records, Total fetched: 2200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2200
# Fetched 100 new records, Total fetched: 2300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2300
# Fetched 100 new records, Total fetched: 2400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2400
# Fetched 100 new records, Total fetched: 2500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2500
# Fetched 100 new records, Total fetched: 2600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2600
# Fetched 100 new records, Total fetched: 2700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2700
# Fetched 100 new records, Total fetched: 2800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2800
# Fetched 17 new records, Total fetched: 2817
# Exiting loop, fetched less than 100 records.
# Fetched 2817 records for Engagement.
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 0
# Fetched 100 new records, Total fetched: 100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 100
# Fetched 100 new records, Total fetched: 200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 200
# Fetched 100 new records, Total fetched: 300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 300
# Fetched 100 new records, Total fetched: 400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 400
# Fetched 100 new records, Total fetched: 500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 500
# Fetched 100 new records, Total fetched: 600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 600
# Fetched 100 new records, Total fetched: 700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 700
# Fetched 100 new records, Total fetched: 800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 800
# Fetched 100 new records, Total fetched: 900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 900
# Fetched 100 new records, Total fetched: 1000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1000
# Fetched 100 new records, Total fetched: 1100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1100
# Fetched 100 new records, Total fetched: 1200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1200
# Fetched 100 new records, Total fetched: 1300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1300
# Fetched 100 new records, Total fetched: 1400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1400
# Fetched 100 new records, Total fetched: 1500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1500
# Fetched 100 new records, Total fetched: 1600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1600
# Fetched 100 new records, Total fetched: 1700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1700
# Fetched 100 new records, Total fetched: 1800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1800
# Fetched 100 new records, Total fetched: 1900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1900
# Fetched 100 new records, Total fetched: 2000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2000
# Fetched 32 new records, Total fetched: 2032
# Exiting loop, fetched less than 100 records.
# Fetched 2032 records for Engagement.
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 0
# Fetched 100 new records, Total fetched: 100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 100
# Fetched 100 new records, Total fetched: 200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 200
# Fetched 100 new records, Total fetched: 300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 300
# Fetched 100 new records, Total fetched: 400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 400
# Fetched 100 new records, Total fetched: 500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 500
# Fetched 100 new records, Total fetched: 600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 600
# Fetched 100 new records, Total fetched: 700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 700
# Fetched 100 new records, Total fetched: 800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 800
# Fetched 100 new records, Total fetched: 900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 900
# Fetched 100 new records, Total fetched: 1000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1000
# Fetched 100 new records, Total fetched: 1100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1100
# Fetched 100 new records, Total fetched: 1200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1200
# Fetched 100 new records, Total fetched: 1300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1300
# Fetched 100 new records, Total fetched: 1400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1400
# Fetched 100 new records, Total fetched: 1500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1500
# Fetched 100 new records, Total fetched: 1600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1600
# Fetched 100 new records, Total fetched: 1700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1700
# Fetched 100 new records, Total fetched: 1800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1800
# Fetched 100 new records, Total fetched: 1900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1900
# Fetched 100 new records, Total fetched: 2000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2000
# Fetched 100 new records, Total fetched: 2100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2100
# Fetched 100 new records, Total fetched: 2200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2200
# Fetched 100 new records, Total fetched: 2300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2300
# Fetched 100 new records, Total fetched: 2400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2400
# Fetched 100 new records, Total fetched: 2500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2500
# Fetched 100 new records, Total fetched: 2600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2600
# Fetched 100 new records, Total fetched: 2700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2700
# Fetched 100 new records, Total fetched: 2800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2800
# Fetched 100 new records, Total fetched: 2900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2900
# Fetched 100 new records, Total fetched: 3000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3000
# Fetched 100 new records, Total fetched: 3100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3100
# Fetched 100 new records, Total fetched: 3200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3200
# Fetched 100 new records, Total fetched: 3300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3300
# Fetched 100 new records, Total fetched: 3400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3400
# Fetched 100 new records, Total fetched: 3500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3500
# Fetched 100 new records, Total fetched: 3600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3600
# Fetched 100 new records, Total fetched: 3700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3700
# Fetched 100 new records, Total fetched: 3800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3800
# Fetched 100 new records, Total fetched: 3900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3900
# Fetched 100 new records, Total fetched: 4000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4000
# Fetched 29 new records, Total fetched: 4029
# Exiting loop, fetched less than 100 records.
# Fetched 4029 records for Engagement.
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 0
# Fetched 100 new records, Total fetched: 100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 100
# Fetched 100 new records, Total fetched: 200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 200
# Fetched 100 new records, Total fetched: 300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 300
# Fetched 100 new records, Total fetched: 400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 400
# Fetched 100 new records, Total fetched: 500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 500
# Fetched 100 new records, Total fetched: 600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 600
# Fetched 100 new records, Total fetched: 700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 700
# Fetched 100 new records, Total fetched: 800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 800
# Fetched 100 new records, Total fetched: 900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 900
# Fetched 100 new records, Total fetched: 1000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1000
# Fetched 100 new records, Total fetched: 1100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1100
# Fetched 100 new records, Total fetched: 1200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1200
# Fetched 100 new records, Total fetched: 1300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1300
# Fetched 100 new records, Total fetched: 1400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1400
# Fetched 100 new records, Total fetched: 1500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1500
# Fetched 100 new records, Total fetched: 1600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1600
# Fetched 100 new records, Total fetched: 1700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1700
# Fetched 100 new records, Total fetched: 1800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1800
# Fetched 100 new records, Total fetched: 1900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1900
# Fetched 100 new records, Total fetched: 2000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2000
# Fetched 100 new records, Total fetched: 2100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2100
# Fetched 100 new records, Total fetched: 2200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2200
# Fetched 100 new records, Total fetched: 2300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2300
# Fetched 100 new records, Total fetched: 2400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2400
# Fetched 100 new records, Total fetched: 2500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2500
# Fetched 100 new records, Total fetched: 2600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2600
# Fetched 100 new records, Total fetched: 2700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2700
# Fetched 100 new records, Total fetched: 2800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2800
# Fetched 100 new records, Total fetched: 2900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2900
# Fetched 100 new records, Total fetched: 3000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3000
# Fetched 100 new records, Total fetched: 3100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3100
# Fetched 100 new records, Total fetched: 3200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3200
# Fetched 100 new records, Total fetched: 3300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3300
# Fetched 100 new records, Total fetched: 3400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3400
# Fetched 100 new records, Total fetched: 3500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3500
# Fetched 100 new records, Total fetched: 3600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3600
# Fetched 100 new records, Total fetched: 3700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3700
# Fetched 100 new records, Total fetched: 3800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3800
# Fetched 100 new records, Total fetched: 3900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3900
# Fetched 100 new records, Total fetched: 4000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4000
# Fetched 100 new records, Total fetched: 4100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4100
# Fetched 100 new records, Total fetched: 4200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4200
# Fetched 100 new records, Total fetched: 4300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4300
# Fetched 100 new records, Total fetched: 4400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4400
# Fetched 100 new records, Total fetched: 4500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4500
# Fetched 100 new records, Total fetched: 4600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4600
# Fetched 100 new records, Total fetched: 4700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4700
# Fetched 100 new records, Total fetched: 4800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4800
# Fetched 100 new records, Total fetched: 4900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4900
# Fetched 100 new records, Total fetched: 5000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5000
# Fetched 100 new records, Total fetched: 5100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5100
# Fetched 100 new records, Total fetched: 5200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5200
# Fetched 100 new records, Total fetched: 5300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5300
# Fetched 100 new records, Total fetched: 5400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5400
# Fetched 100 new records, Total fetched: 5500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5500
# Fetched 100 new records, Total fetched: 5600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5600
# Fetched 100 new records, Total fetched: 5700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5700
# Fetched 100 new records, Total fetched: 5800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5800
# Fetched 100 new records, Total fetched: 5900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5900
# Fetched 100 new records, Total fetched: 6000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 6000
# Fetched 100 new records, Total fetched: 6100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 6100
# Fetched 100 new records, Total fetched: 6200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 6200
# Fetched 100 new records, Total fetched: 6300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 6300
# Fetched 100 new records, Total fetched: 6400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 6400
# Fetched 100 new records, Total fetched: 6500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 6500
# Fetched 41 new records, Total fetched: 6541
# Exiting loop, fetched less than 100 records.
# Fetched 6541 records for Engagement.
# Processing admissions group: Colleen 2K22NOV1848
# Processing admissions group: Charmaine 2K21JUL2090
# Processing admissions group: CHINAZVO 2K22NOV0980
# Processing admissions group: Davison 2K22SEP1428
# Processing admissions group: Prince 2K21DEC2039
# Processing admissions group: Hove 2K23MAR2348
# Processing admissions group: John 2K21DEC0608
# Processing admissions group: Jonathan 2K23JUN1495
# Processing admissions group: Kimberly 2K22DEC1492
# Processing admissions group: KUDAKWASHE 2K23FEB1701
# Processing admissions group: AUSTIN 2K21SEP0418
# Processing admissions group: Kudziwaishe 2K22NOV0590
# Processing admissions group: Linda 2K23JAN2363
# Processing admissions group: Carren 2K21NOV1275
# Processing admissions group: Miriam 2K22MAY1702
# Processing admissions group: Tafadzwa 2K23JAN2336
# Processing admissions group: Moreblessing 2K22AUG1328
# Processing admissions group: Patron 2K21JUN0812
# Processing admissions group: Precious 2K22AUG2211
# Processing admissions group: Cleopatra 2K23JAN2354
# Processing admissions group: Redeem 2K22SEP1909
# Processing admissions group: Shammah 2K23JAN2795
# Processing admissions group: Shyne 2k21OCT0950
# Processing admissions group: Talent 2K22APR1238
# Processing admissions group: Thubelihle 2K23FEB1715
# Processing admissions group: Tinevimbo 2K21DEC1757
# Processing admissions group: Tino 2K22OCT2525
# Processing admissions group: Tracy 2K22FEB1632
# Processing admissions group: Vincient 2K23JAN2402
# Processing admissions group: Allan 2K23JUL1010
# Processing admissions group: Anesuishe 2K22DEC0852
# Processing admissions group: Antony 2K21DEC0111
# Processing admissions group: Arthur 2K22MAR1907
# Processing admissions group: Audrey 2K22JAN1990
# Processing admissions group: Aznar 2K21APR2744
# Processing admissions group: Bervely 2K23FEB2310
# Processing admissions group: Blessed 2K22JUN0125
# Processing admissions group: Brian 2k21JUN0218
# Processing admissions group: Bright 2K22NOV1526
# Processing admissions group: BRYN 2K23JAN0528
# Processing admissions group: Caleb 2K22NOV1272
# Processing admissions group: Candis 2K22NOV2392
# Processing admissions group: Sheunesu 2K22JAN2012
# Processing admissions group: Meghan 2K22MAR0923
# Processing admissions group: Covenant 2K23MAY1841
# Processing admissions group: Daniel 2K21SEP0775
# Processing admissions group: Danzel 2K22DEC2714
# Processing admissions group: Billy 2K21JUN1680
# Processing admissions group: Elina 2K23JAN1702
# Processing admissions group: Emelia 2K23JAN2432
# Processing admissions group: Eric 2K22MAR1927
# Processing admissions group: Esnaty 2K23JAN1438
# Processing admissions group: Fanwell 2K22NOV1427
# Processing admissions group: Felix 2K22NOV2805
# Processing admissions group: Natasha 2K22DEC1908
# Processing admissions group: Asher 2K23APR2547
# Processing admissions group: Holiness 2K22FEB1130
# Processing admissions group: Joe 2K23JAN1402
# Processing admissions group: Joel 2K21DEC1167
# Processing admissions group: Joseph 2K23JAN1602
# Processing admissions group: Keith 2K22MAY0248
# Processing admissions group: Kudzaiishe 2K23JAN1805
# Processing admissions group: Kuzivakwashe 2K23FEB1895
# Processing admissions group: LISFORD 2K22DEC1308
# Processing admissions group: Lorraine 2K23JAN0518
# Processing admissions group: Maggie 2K21APR2662
# Processing admissions group: Abigail 2K22DEC2057
# Processing admissions group: Makanaka 2K23MAY1103
# Processing admissions group: Makanakaishe 2K21MAR2256
# Processing admissions group: Kudzanai 2K21APR2637
# Processing admissions group: Nicole 2K22FEB1010
# Processing admissions group: Vimbayi 2K22OCT1490
# Processing admissions group: Panashe 2K21JUL1642
# Processing admissions group: Martin 2K21JUL1410
# Processing admissions group: Mary 2K21MAY1750
# Processing admissions group: MASIKA 2K21SEP0430
# Processing admissions group: Miriam 2K22FEB0209
# Processing admissions group: Kelly 2K21MAR1946
# Processing admissions group: Melisa 2K21MAY3162
# Processing admissions group: Michael 2K22MAR0392
# Processing admissions group: Mishael 2K23JUL2191R
# Processing admissions group: Tavanashe 2K23JUN0959
# Processing admissions group: Sandra 2K22AUG1904
# Processing admissions group: Munyaradzi 2K21NOV2274
# Processing admissions group: Ngonidzashe 2K22FEB0120
# Processing admissions group: Tatenda 2K21MAY0740
# Processing admissions group: Natasha 2K22DEC2336
# Processing admissions group: Mayibongwe 2K22OCT0353
# Processing admissions group: Kelly 2K22FEB1801
# Processing admissions group: Nicolene 2K19DEC0701
# Processing admissions group: Nkosinothando 2K21OCT2175
# Processing admissions group: NYARADZO 2K21AUG2703
# Processing admissions group: Nyasha 2K22AUG2601
# Processing admissions group: Panashe 2K23JUN0795
# Processing admissions group: Panashe 2K22JUN3006
# Processing admissions group: Panashe 2K22MAR1786
# Processing admissions group: Patience 2K21DEC3080
# Processing admissions group: Proud 2K22MAY2350
# Processing admissions group: Tatenda 2K22DEC1391
# Processing admissions group: Prosper 2K22JAN1517
# Processing admissions group: Rachael 2K21AUG0913
# Processing admissions group: Ratidzai 2K21MAY1779
# Processing admissions group: Raymond 2K23FEB1710
# Processing admissions group: Ropafadzo 2K23MAY1310
# Processing admissions group: Rutendo 2K22DEC2309
# Processing admissions group: Salma 2K22APR2555
# Processing admissions group: Shanice 2K21APR2123
# Processing admissions group: SHANTEL 2K22AUG0327
# Processing admissions group: Sharon 2K21APR0688
# Processing admissions group: Shumirai 2K21AUG1008
# Processing admissions group: Sikholiwe 2K22JUN1137
# Processing admissions group: Arnold 2K22DEC1502
# Processing admissions group: Sisasenkosi 2K21JUL0651
# Processing admissions group: Tadiwa 2K21AUG2650
# Processing admissions group: Takudzwanashe 2K22DEC0802
# Processing admissions group: Tanaka 2K20OCT0968
# Processing admissions group: Tatenda 2K23JAN1035
# Processing admissions group: THANDIWE 2K23JAN1852
# Processing admissions group: Thubalami 2K22DEC1256
# Processing admissions group: Tinashe 2K22NOV2395
# Processing admissions group: Tinaye 2K21SEP0890
# Processing admissions group: Tricia 2K22APR0918
# Processing admissions group: Twazanga 2K22DEC2093
# Processing admissions group: Utloile 2K23JAN1193
# Processing admissions group: Vanessa 2K22AUG1319
# Processing admissions group: Vincent 2K21AUG1735
# Processing admissions group: Yananai 2K22MAY1707
# Processing admissions group: Abisai 2K22DEC1224
# Processing admissions group: Abigail 2K23JAN1939
# Processing admissions group: Abigail 2K21NOV1559
# Processing admissions group: Adella 2K22FEB2869
# Processing admissions group: Alvin 2K20SEP1918
# Processing admissions group: Anesu 2K22JUL2876
# Processing admissions group: Anesuishe 2K23JAN0525
# Processing admissions group: Ashleigh 2K20AUG2357
# Processing admissions group: Austin 2K23JAN2592
# Processing admissions group: Ayanda 2K22JAN1311
# Processing admissions group: Banenkosi 2K21JAN1519
# Processing admissions group: Blessing 2K22NOV0123
# Processing admissions group: Brita 2K22FEB0232
# Processing admissions group: Calvin 2K21OCT2010
# Processing admissions group: Catherine 2K21JAN0544
# Processing admissions group: Charmaine 2K22AUG2234
# Processing admissions group: Chiedza 2K22FEB1213
# Processing admissions group: Comedy 2K22MAR0380
# Processing admissions group: Courage 2K23MAY0552
# Processing admissions group: Creed 2K22DEC0825
# Processing admissions group: Delight 2K22AUG1266
# Processing admissions group: Desire 2K22SEP0347
# Processing admissions group: Edwin 2K22OCT2589
# Processing admissions group: Rutendo 2K20SEP0717
# Processing admissions group: Fungai 2K22SEP0923
# Processing admissions group: Gerald 2K23JAN1616
# Processing admissions group: Ashley 2K23FEB0130
# Processing admissions group: Hazel 2K22JAN1301
# Processing admissions group: Tinotenda 2K21DEC2032
# Processing admissions group: Nkosilomusa 2K22FEB1940
# Processing admissions group: Jeston 2K22SEP0107
# Processing admissions group: John 2K22AUG0468
# Processing admissions group: Josh 2K22FEB1429
# Processing admissions group: Katelyn 2K22AUG1307
# Processing admissions group: Katendi 2K23FEB1022
# Processing admissions group: Keith 2K23MAR3130R
# Processing admissions group: Kelly 2K23APR1564
# Processing admissions group: Kester 2K22JUL1415
# Processing admissions group: Kudakwashe 2K21JAN1549
# Processing admissions group: Kudzaishe 2K21OCT0502
# Processing admissions group: Leona 2K23MAR2929
# Processing admissions group: LINDA 2K21SEP2213
# Processing admissions group: Lorraine 2K21OCT2331
# Processing admissions group: Lorraine 2K23APR2606
# Processing admissions group: Lorraine 2K22MAY2717
# Processing admissions group: Lynette 2K22AUG2966
# Processing admissions group: Nicole 2K22FEB0526
# Processing admissions group: Mafara 2K21OCT2106
# Processing admissions group: Morefaith 2K22APR2640
# Processing admissions group: Marlene 2K21NOV0268
# Processing admissions group: Patience 2K22SEP2008R
# Processing admissions group: Tatenda 2K22JUN1450
# Processing admissions group: Mellisa 2K22MAR2105
# Processing admissions group: Michell 2K22MAY1924
# Processing admissions group: Mitchelle 2K22NOV2312
# Processing admissions group: Moreblessing 2K22NOV2358
# Processing admissions group: Gilselda 2K21SEP0143
# Processing admissions group: Tariro 2K23JAN0203
# Processing admissions group: Takudzwa 2K22MAR0136R
# Processing admissions group: Melanie 2K23FEB0409
# Processing admissions group: Natalie 2K22SEP2234
# Processing admissions group: Nathaniel 2K23MAR1548
# Processing admissions group: Nicassio 2K22JUL2945
# Processing admissions group: Nigel 2K23APR0768
# Processing admissions group: Nokutenda 2K23APR1822
# Processing admissions group: Nozizwe 2K23FEB2111R
# Processing admissions group: Nqobizitha 2K20NOV3032
# Processing admissions group: Emmanuel 2K22JAN1094
# Processing admissions group: Nyasha 2K23APR0412
# Processing admissions group: Nyasha 2K22FEB0350
# Processing admissions group: Nyashadzashe 2K23MAR0433
# Processing admissions group: Ephinas 2K23MAR0322
# Processing admissions group: Obey 2K22MAY0638
# Processing admissions group: Hakeem 2K20SEP2423
# Processing admissions group: Leanet 2K21JAN0241
# Processing admissions group: Pamella 2K22DEC0848
# Processing admissions group: Panashe 2K21JAN1157
# Processing admissions group: Panashe 2K22MAR2257
# Processing admissions group: Pardon 2K22FEB0703
# Processing admissions group: Patience 2K23MAR2355R
# Processing admissions group: Prisca 2K20DEC032
# Processing admissions group: Progress 2K22NOV1428
# Processing admissions group: Providence 2K21OCT0173
# Processing admissions group: Ropafadzo 2K21JUL0642
# Processing admissions group: Rufaro 2K23JUN1220
# Processing admissions group: RUTH 2K23MAR2137
# Processing admissions group: Ryan 2K23JAN1318
# Processing admissions group: Shalom 2K22APR0802
# Processing admissions group: Shantel 2K23JAN0755
# Processing admissions group: Shawn 2K22NOV0328
# Processing admissions group: Shekinah 2K22MAR0242
# Processing admissions group: Shingai 2K22JUN0909R
# Processing admissions group: Sibongile 2K22AUG2201
# Processing admissions group: Silence 2K23JAN0337
# Processing admissions group: Simphiwe 2K22DEC0692
# Processing admissions group: Tatire 2K21DEC2464
# Processing admissions group: Tadiwa 2K22AUG1645
# Processing admissions group: Tadiwanashe 2K22DEC1367
# Processing admissions group: Tafadzwa 2K22MAR2408
# Processing admissions group: Tafadzwa 2K20AUG2412
# Processing admissions group: Tafadzwa 2K22JUN2952
# Processing admissions group: Takudzwa 2K22OCT1484
# Processing admissions group: Talent 2K22MAY1047
# Processing admissions group: Tanyaradzwa 2K22JUL2532
# Processing admissions group: Tanyaradzwa 2K22NOV3047
# Processing admissions group: Taonga 2K22DEC2048
# Processing admissions group: Courtney 2K23MAR1742
# Processing admissions group: TARIRO 2K22MAR1645
# Processing admissions group: Tatenda 2K21JAN0853
# Processing admissions group: Tecla 2K22FEB0452
# Processing admissions group: Tendai 2K21MAY0750
# Processing admissions group: Thelma 2K23JUL1538
# Processing admissions group: Thomas 2K22JUN2212
# Processing admissions group: Tinevimbo 2K22JUN2488
# Processing admissions group: Tsitsi 2K22NOV1859
# Processing admissions group: Vinah 2K22OCT2821
# Processing admissions group: Wadzanai 2K21AUG2047
# Processing admissions group: Wisdom 2K22JUL2282
# Processing admissions group: Yolanda 2K22APR2512
# Processing admissions group: Yvonne 2K23MAR0662
# Processing admissions group: Zolani 2K23FEB0185
# Processing admissions group: Aaliyah 2K22APR1544
# Processing admissions group: Abdel 2K21APR2269
# Processing admissions group: Agutha 2K23FEB1751
# Processing admissions group: Aisha 2K21SEP2932
# Processing admissions group: ANESU 2K22AUG2287
# Processing admissions group: Angeline 2K21JUN0170
# Processing admissions group: Anotidaishe 2K21JUN2938
# Processing admissions group: Ashell 2K21NOV1846
# Processing admissions group: Barnabas 2K22SEP0134
# Processing admissions group: Bertha 2K21NOV1717
# Processing admissions group: Blessing 2K22JUL2695
# Processing admissions group: Blessing 2K22FEB0342
# Processing admissions group: Brian 2K22SEP2421
# Processing admissions group: Brooke 2K23MAY0260
# Processing admissions group: Shantel 2K21SEP0892
# Processing admissions group: Casandra 2K21JUL2714
# Processing admissions group: QUINTON 2K23MAY1224
# Processing admissions group: Chantelle 2K22SEP1922R
# Processing admissions group: Chelsea 2K20NOV248
# Processing admissions group: Chiedza 2K22APR3036
# Processing admissions group: Chikwanha 2K22FEB0468
# Processing admissions group: Chinyama 2K23JUN0797
# Processing admissions group: Chirenje 2K22MAR1477
# Processing admissions group: Clayton 2K22JUN2175
# Processing admissions group: Cloudious 2K23FEB2813
# Processing admissions group: Dadirai 2K21OCT1602
# Processing admissions group: Dakarai 2K21AUG0949
# Processing admissions group: Delight 2K20SEP2458
# Processing admissions group: DENZEL 2K23JAN3039
# Processing admissions group: Dezyline 2K22SEP2368
# Processing admissions group: Doozy 2K21MAY2269
# Processing admissions group: Dryad 2K21MAY2277
# Processing admissions group: Dumoluhle 2K22MAR1510
# Processing admissions group: Edgar 2K23MAR0918
# Processing admissions group: Egnes 2K21SEP0790
# Processing admissions group: Amarachkwu 2K21JUL2129
# Processing admissions group: Elton 2K23JAN0919
# Processing admissions group: Eugenia 2K21FEB2538
# Processing admissions group: Fanuel 2K22NOV1104
# Processing admissions group: Melody 2K20SEP3061
# Processing admissions group: Fungisai 2K22JUN2116
# Processing admissions group: Gelean 2K22JAN1857
# Processing admissions group: Gervais 2K23JAN1002
# Processing admissions group: Gracious 2K22JUL1545
# Processing admissions group: Hazel 2K23JAN0642
# Processing admissions group: Heather 2K20AUG1904
# Processing admissions group: Heggah 2K23FEB0452
# Processing admissions group: Hester 2K23FEB1331
# Processing admissions group: Hilario 2K23FEB0134
# Processing admissions group: Ivy 2K23FEB1044
# Processing admissions group: Jenipher 2K22JAN1307
# Processing admissions group: Jeremiah 2K23MAR0113
# Processing admissions group: Juliet 2K23JAN0401
# Processing admissions group: Justine 2K21SEP3082
# Processing admissions group: Sekwila 2K23MAR2287
# Processing admissions group: Kimberly 2K23MAY1595
# Processing admissions group: King 2K21APR0942
# Processing admissions group: Kudakwashe 2K22JUN2309
# Processing admissions group: Kudzai 2K21NOV1662
# Processing admissions group: Kudzai 2K21OCT2805
# Processing admissions group: Kudzanai 2K22OCT1748
# Processing admissions group: Learnfirst 2K22JUN1753
# Processing admissions group: Lerato 2K22JAN1734
# Processing admissions group: Leslie 2K21DEC2023
# Processing admissions group: Linnety 2K21OCT2204
# Processing admissions group: Loice 2K22OCT1152
# Processing admissions group: Lorraine 2K21NOV2505
# Processing admissions group: Lydia 2K23APR1845
# Processing admissions group: Vimbikai 2K22MAY0732
# Processing admissions group: Manwere 2K21NOV1306
# Processing admissions group: Margret 2K21MAR0141
# Processing admissions group: Marlon 2K23FEB1490
# Processing admissions group: Marvellous 2K22AUG0965
# Processing admissions group: Tracy 2K23JAN3047
# Processing admissions group: Ruth 2K22MAY1035
# Processing admissions group: Kudzai 2K22MAR0265
# Processing admissions group: Deon 2K22JUL0770
# Processing admissions group: Mayanga 2K21AUG1756
# Processing admissions group: Mayibongwe 2K21OCT0742
# Processing admissions group: Mbongeni 2K21AUG1651
# Processing admissions group: Mederleen 2K21AUG2435
# Processing admissions group: Mercy 2K21FEB0318
# Processing admissions group: Mihlayonke 2K22MAY1103
# Processing admissions group: Mitchell 2K22AUG2002
# Processing admissions group: Brian 2K22APR2132
# Processing admissions group: Liberty 2K21OCT1379
# Processing admissions group: Tawananyasha 2K21JUN2284
# Processing admissions group: Winscencia 2K21NOV1208
# Processing admissions group: Munyaradzi 2K22OCT2338
# Processing admissions group: Blessed 2K22NOV1796
# Processing admissions group: Tawanda 2K21MAR0336
# Processing admissions group: Patricia 2K22JAN2032
# Processing admissions group: Nalesia 2K20AUG2630
# Processing admissions group: Nontokozo 2K22MAY0312
# Processing admissions group: Siphosenkosi 2K22MAY1064
# Processing admissions group: Neville 2K22NOV1994
# Processing admissions group: Ngonidzashe 2K23FEB2727
# Processing admissions group: NGQABUTHO 2K22MAR2370
# Processing admissions group: Prince 2K22NOV1211
# Processing admissions group: Nyasha 2K23FEB1457
# Processing admissions group: Nyasha 2K21FEB2541
# Processing admissions group: Omega 2K22MAR0230
# Processing admissions group: Patience 2K21JUN1580
# Processing admissions group: Perseverance 2K20DEC0958
# Processing admissions group: Persistance 2K21AUG1609
# Processing admissions group: Precious 2K22APR2632
# Processing admissions group: Prestige 2K22MAY2008
# Processing admissions group: Primrose 2K22JAN1456
# Processing admissions group: Prince 2K22APR0578
# Processing admissions group: Princess 2K22JAN1040
# Processing admissions group: Rachael 2K23MAY1224
# Processing admissions group: Rumbidzai 2K22MAY2045
# Processing admissions group: Runyararo 2K21AUG1391
# Processing admissions group: Ruth 2K22FEB1512
# Processing admissions group: Ruvarashe 2K21MAY3170
# Processing admissions group: Tinotenda 2K23JAN0971
# Processing admissions group: Sacred 2K23JAN2012
# Processing admissions group: Sandra 2K22FEB1412
# Processing admissions group: Shalom 2K21MAY0347
# Processing admissions group: Shalom 2K23FEB1391
# Processing admissions group: Shamar 2K21JUL0274
# Processing admissions group: Shantel 2K23MAR1544
# Processing admissions group: Shanyce 2K22MAY0622
# Processing admissions group: Sharmaine 2K22SEP2278R
# Processing admissions group: Sibonginkhosi 2K22NOV1738
# Processing admissions group: Grace 2K23MAY0455
# Processing admissions group: Simbarashe 2K21SEP0882
# Processing admissions group: Faith 2K23APR2075
# Processing admissions group: Sindisiwe 2K22NOV1225
# Processing admissions group: Canfred 2K21OCT2219
# Processing admissions group: Stanford 2K21NOV1121
# Processing admissions group: STEPHEN 2K23JUN1717
# Processing admissions group: Tadiwanashe 2K21JUL1213
# Processing admissions group: Tadiwanashe 2K23MAR0392
# Processing admissions group: Tafadzwa 2K22APR1818
# Processing admissions group: Takudzwa 2K22MAR2194
# Processing admissions group: Takunda 2K22JUL2606
# Processing admissions group: Tanaka 2K21OCT2511
# Processing admissions group: Tanaka 2K22FEB0783
# Processing admissions group: Tanaka 2K22JUN2822
# Processing admissions group: Tania 2K22JUL0718R
# Processing admissions group: Tannya 2K22MAY1634
# Processing admissions group: Tanyaradzwa 2K22APR1440
# Processing admissions group: Tanyaradzwa 2K22AUG2364
# Processing admissions group: Tanyaradzwa 2K21JUN0787
# Processing admissions group: Tapiwa 2K22JAN3119
# Processing admissions group: Tatenda 2K21JUL2071
# Processing admissions group: Tatenda 2K23MAR2408
# Processing admissions group: Tatenda 2K21AUG0615
# Processing admissions group: Tendai 2K22FEB1430
# Processing admissions group: Tendai 2K22FEB0818
# Processing admissions group: Thelma 2K21OCT2080
# Processing admissions group: Tinashe 2K21DEC1737
# Processing admissions group: Tinashe 2K21JAN1333
# Processing admissions group: Tinashe 2K22NOV0581
# Processing admissions group: TINOTENDA 2K23FEB0420
# Processing admissions group: Tinotenda 2K22DEC1692
# Processing admissions group: Tinoziva 2K22APR2912
# Processing admissions group: Trevor 2K22MAY0625
# Processing admissions group: Unique 2K22AUG2417
# Processing admissions group: Varaidzo 2K22FEB0260
# Processing admissions group: Virginia 2K23JAN1018
# Processing admissions group: VITTALIS 2K23FEB1728
# Processing admissions group: Vivian 2K21FEB1749
# Processing admissions group: Tanyaradzwa 2K21NOV2220
# Processing admissions group: Washington 2K22OCT2597
# Processing admissions group: Whitney 2K23JAN1715
# Processing admissions group: Wilbert 2K23JAN0545
# Processing admissions group: Yvette 2K22SEP1709
# Processing admissions group: Annette 2K22OCT1753
# Processing admissions group: Belief 2K23JUL0835R
# Processing admissions group: Blessing 2K21DEC1425
# Processing admissions group: Clemence 2K22DEC0539
# Processing admissions group: Conrad 2K22AUG2993
# Processing admissions group: Tadiwanashe 2K22NOV2282
# Processing admissions group: Hazel 2K22DEC0522
# Processing admissions group: Immanuel 2K22OCT1528
# Processing admissions group: Kelvin 2K22NOV2507
# Processing admissions group: Lyosa 2K23JUL1245
# Processing admissions group: Moline 2K22AUG2917
# Processing admissions group: Muchimba 2K22JUL1934
# Processing admissions group: Munashe 2K22OCT1202
# Processing admissions group: Munashe 2K22NOV2209
# Processing admissions group: Munashe 2K220CT3145
# Processing admissions group: Alvin 2K22APR0784
# Processing admissions group: Muloongo 2K23JUL1295
# Processing admissions group: Merlen 2K22AUG1660
# Processing admissions group: Pious 2K22MAY1745
# Processing admissions group: Precious 2K22DEC0743
# Processing admissions group: Ratchel 2K22OCT1257
# Processing admissions group: Rhoda 2K22DEC0806
# Processing admissions group: Rutendo 2K23JUL3101
# Processing admissions group: Senamiso 2K22DEC0698
# Processing admissions group: Precious 2K22DEC0501
# Processing admissions group: Sithokozile 2K22SEP1994
# Processing admissions group: Rutendo 2K22SEP0896
# Processing admissions group: Gwitira 2K22SEP1916R
# Processing admissions group: Tashia 2K22DEC2750
# Processing admissions group: Tinotenda 2K22NOV1939R
# Processing admissions group: Tonderai 2K22OCT1828
# Processing admissions group: Wasikananka 2K22NOV1092
# Processing admissions group: Yeukai 2K22DEC1330
# Processing admissions group: Anna 2K21NOV3059
# Processing admissions group: Benedict 2K23MAR0745
# Processing admissions group: Brandon 2K21NOV1824
# Processing admissions group: Charlene 2K23JAN1792
# Processing admissions group: Takudzwa 2K22OCT1358
# Processing admissions group: Mellisa 2K22JUL2065
# Processing admissions group: Taisha 2K23APR0737
# Processing admissions group: Clarisah 2K22SEP3045
# Processing admissions group: DARLEEN 2K21MAR2692
# Processing admissions group: Denise 2K22DEC0689
# Processing admissions group: Diouf 2K21NOV1534
# Processing admissions group: Dolly 2K21APR2671
# Processing admissions group: Elisha 2K21MAY1376
# Processing admissions group: Elsie 2K22MAR2185
# Processing admissions group: Godknows 2K23JAN1247
# Processing admissions group: Tanatswa 2K22JUN1112
# Processing admissions group: Kelvin 2K22AUG1220
# Processing admissions group: Kudakwashe 2K21APR1730
# Processing admissions group: Loridapatt 2K20OCT0514
# Processing admissions group: Luyanda 2K23FEB1476
# Processing admissions group: Makanatsa 2K23JAN2364R
# ...
# Processing admissions group: Susan 2K23MAY2338
# Processing admissions group: Tadiwanashe 2K22JUN1129
# Processing admissions group: Tafadzwa 2K22FEB1292
# Processing admissions group: Tafadzwa 2K21MAR1152
# Processing admissions group: Takudzwa 2K23JAN1025
# Processing admissions group: Tanatswa 2K21JAN0415
# Processing admissions group: Tatenda 2K23MAR0310
# Processing admissions group: Thulani 2K22MAY1470
# Processing admissions group: TINASHE 2K23JAN2466
# Processing admissions group: Tinashe 2K22SEP0752
# Processing admissions group: Tinotendaishe 2K22SEP0319
# Processing admissions group: Vanitor 2K21DEC0202
# Processing admissions group: Andipa 2K22MAY2530
# Processing admissions group: Chimoga 2K22JUL1301
# Processing admissions group: Tinashe 2K22NOV1402
# Processing admissions group: Shaun 2K22DEC0338
# Processing admissions group: Rejoice 2K22DEC2030
# Processing admissions group: Valerie 2K23JAN0556
# Processing admissions group: Amanda 2K22MAY0602
# Processing admissions group: Keith 2K22SEP0802
# Processing admissions group: Tanaka 2K20JAN2365
# Processing admissions group: Rutendo 2K20NOV2362
# Processing admissions group: Panashe 2K21JAN0509
# Processing admissions group: Panashe 2K21JAN2074
# Processing admissions group: Simon 2K21MAR2556
# Processing admissions group: Sandra 2K21MAR1864
# Processing admissions group: Nyama 2K21APR0574
# Processing admissions group: Thinkmore 2K21APR0325
# Processing admissions group: Takudzwanashe 2K21APR1912
# Processing admissions group: Elijah 2K21MAY0604
# Processing admissions group: Adeline 2K21MAY1329
# Processing admissions group: Mellisa 2K21MAY1914
# Processing admissions group: Linda 2K21MAY3125
# Processing admissions group: Princess 2K21JUN1407
# Processing admissions group: Nkosisikelela 2K21JUN2909
# Processing admissions group: Ngwenya 2K21JUL0514
# Processing admissions group: Perpetua 2K21JUL0761
# Processing admissions group: Tafadzwa 2K21JUL1583
# Processing admissions group: DANIEL 2K21JUL2703
# Processing admissions group: Ndapiwa 2K21JUL2707
# Processing admissions group: Lwandile 2K21JUL2722
# Processing admissions group: Vimbainashe 2K21JUL2735
# Processing admissions group: Lacious 2K21AUG1190
# Processing admissions group: Jonathan 2K21AUG1179
# Processing admissions group: Sharai 2K21AUG1859
# Processing admissions group: Mcspencer 2K21AUG2774
# Processing admissions group: Kudakwashe 2K21AUG2710
# Processing admissions group: Anopaishe 2K21AUG2658
# Processing admissions group: Andrew 2K21AUG2603
# Processing admissions group: Emmanuel 2K21SEP0101
# Processing admissions group: Mthulisi 2K21SEP0289
# Processing admissions group: Elizabeth 2K21SEP0673R
# Processing admissions group: Tinaye 2K21SEP0933
# Processing admissions group: Innocent 2K21SEP1143R
# Processing admissions group: Morgen 2k21SEP2158
# Processing admissions group: Keith 2K21SEP1787
# Processing admissions group: Lucky 2K21SEP2798R
# Processing admissions group: Matungamire 2K21SEP2403
# Processing admissions group: Mitchell 2K21OCT0492
# Processing admissions group: Tswatswa 2K21OCT0602
# Processing admissions group: Elphine 2K21OCT1578R
# Processing admissions group: Mercy 2k21OCT1605
# Processing admissions group: Wadzanai 2K21OCT2125
# Processing admissions group: Rachel 2K21OCT3013
# Processing admissions group: Thabiso 2K21NOV1241
# Processing admissions group: Theresa 2K21NOV1352
# Processing admissions group: Bonface 2K21NOV1783
# Processing admissions group: Changadzo 2K21NOV2953
# Processing admissions group: Fambai 2K21DEC1153
# Processing admissions group: Kelvin 2K22JAN1985
# Processing admissions group: Patience 2K22JAN1966R
# Processing admissions group: Lisben 2K22JAN1892
# Processing admissions group: Asher 2K22JAN2203
# Processing admissions group: Elshebba 2K22MAR0216
# Processing admissions group: Lorraine 2K22MAR2210
# Processing admissions group: Tatenda 2K22MAR2190
# Processing admissions group: Shalom 2K22MAR2556
# Processing admissions group: Munashe 2K22MAR2142
# Processing admissions group: LISA 2K22MAR2589
# Processing admissions group: Thamsanqa 2K22MAR2994
# Processing admissions group: Albert 2K22MAR3194
# Processing admissions group: Sally 2K22APR0722
# Processing admissions group: Melrose 2K22APR1652
# Processing admissions group: Beverley 2K22APR1912
# Processing admissions group: Natalie 2K22APR1572
# Processing admissions group: Winnstone 2K22APR2126
# Processing admissions group: Mupona 2K22APR2660
# Processing admissions group: Tanyaradzwa 2K22APR2382
# Processing admissions group: Nigel 2K22APR2505
# Processing admissions group: Nigel 2K22APR2652
# Processing admissions group: Tadiwanashe 2K22APR2608
# Processing admissions group: Brighton 2K22APR2626
# Processing admissions group: Shamiso 2K22MAY0572
# Processing admissions group: Tecla 2K22MAY1238
# Processing admissions group: Sean 2K22MAY1953
# Processing admissions group: Welshman 2K22MAY1912
# Processing admissions group: Anesu 2K22JUN1424
# Processing admissions group: Prince 2K22JUL0545
# Processing admissions group: Samantha 2K23MAR0203
# Processing admissions group: Tapiwanashe 2K23MAR0134
# Processing admissions group: Tariro 2K23MAR2342
# Processing admissions group: Abigail 2K23AUG1091R
# Processing admissions group: Kudzwai 2K21OCT0468
# Processing admissions group: Kudakwashe 2K23JUN1089
# Processing admissions group: Shammah 2K21JUL1707
# Processing admissions group: Bernadette 2K22AUG1040
# Processing admissions group: Francesca 2K23AUG1892
# Processing admissions group: Nashville 2K23AUG2266R
# Processing admissions group: Gugulethu 2K23AUG1858
# Processing admissions group: Shingirai 2K23AUG2597
# Processing admissions group: Blessing 2K23FEB2334
# Processing admissions group: Brenda 2K23FEB0992
# Processing admissions group: Ashley 2K22MAR1652
# Processing admissions group: Rutendo 2K22MAR1777
# Processing admissions group: Natashe 2K22MAR1410
# Processing admissions group: Rufaro 2K23FEB0692
# Processing admissions group: Allen 2K22SEP2695
# Processing admissions group: Neo 2K23MAY0223
# Processing admissions group: Wilma 2K21SEP0848
# Processing admissions group: Bhekinkosi 2K22OCT2498
# Processing admissions group: Natasha 2K22JAN1001
# Processing admissions group: Courage 2K22JUL1682
# Processing admissions group: Ruth 2K22DEC1240
# Processing admissions group: Ownwell 2K20AUG2760
# Processing admissions group: Charleen 2K23JAN0501
# Processing admissions group: Michael 2K23FEB0902
# Processing admissions group: Praise 2K22NOV1618
# Processing admissions group: Kelvin 2K23JUN0905
# Processing admissions group: Panashe 2K22JUL2904
# Processing admissions group: Takunda 2K22JUL2006
# Processing admissions group: Zvikomborero 2K22JAN2085
# Processing admissions group: Patience 2K21APR0603
# Processing admissions group: Morgan 2K21AUG1303
# Processing admissions group: Tanatswa 2K22DEC0732
# Processing admissions group: Faith 2K22SEP0382
# Processing admissions group: Evans 2K23JAN2728
# Processing admissions group: Tinotenda 2K22MAY0926
# Processing admissions group: Tatenda 2K22OCT2008
# Processing admissions group: Shelter 2K23JUN1598
# Processing admissions group: Trust 2K21JUN0278
# Processing admissions group: Yananisai 2K22JUN1305
# Processing admissions group: Ruwende 2K21JUL3066
# Processing admissions group: Jason 2K22FEB2185
# Processing admissions group: Rufaro 2K23AUG1598
# Processing admissions group: Sharon 2K21JUL0956
# Processing admissions group: Shalom 2K23JUN1242
# Processing admissions group: Denzel 2K21SEP2533
# Processing admissions group: Fadzai 2K22DEC2804
# Processing admissions group: Caroline 2K21OCT2169
# Processing admissions group: Tinotenda 2K22FEB1238
# Processing admissions group: Patience 2K22JAN2180
# Processing admissions group: Ashleigh 2K22FEB1857
# Processing admissions group: Tafadzwa 2K21DEC2705
# Processing admissions group: Tadiwanashe 2K22JAN1322
# Processing admissions group: Jesca 2K22DEC0725
# Processing admissions group: Sharon 2K22FEB2512
# Processing admissions group: Gerald 2K21JUL2002
# Processing admissions group: Rebecca 2K21AUG0737
# Processing admissions group: Kafula 2K23JUL1095
# Processing admissions group: Natasha 2K22MAY1847
# Processing admissions group: Hazel 2k21Nov1805
# Processing admissions group: Brita 2K22AUG1238
# Processing admissions group: Trinity 2K23MAR0313
# Processing admissions group: Angeline 2K23FEB2804
# Processing admissions group: Nyasha 2K23AUG0735
# Processing admissions group: Bradley 2K22MAR2204
# Processing admissions group: Prince 2K20FEB2506
# Processing admissions group: Tsitsi 2K20AUG2927
# Processing admissions group: LILIAN 2K22MAR1412
# Processing admissions group: Tatenda 2K22FEB1753
# Processing admissions group: Vincent 2K22JUN1007
# Processing admissions group: Takudzwa 2K22AUG1031
# Processing admissions group: Denise 2K21JUN1085
# Processing admissions group: Mudzuri 2K21MAR0521
# Processing admissions group: Tolerant 2K23JUN2995
# Processing admissions group: Emeni 2K22MAY0922
# Processing admissions group: Mercynay 2K23JUN2895
# Processing admissions group: Vanessa 2K21OCT1834
# Processing admissions group: Amani 2K23AUG0305
# Processing admissions group: Blessing 2K21DEC1302
# Processing admissions group: Lionel 2K21MAY2561
# Processing admissions group: Tendekai 2K21AUG2610
# Processing admissions group: Nigel 2K23MAR1324
# Processing admissions group: Emelda 2K22JUN0346
# Processing admissions group: Hazel 2K23FEB1499
# Processing admissions group: Michael 2K22FEB0824
# Processing admissions group: Tiriwashe 2K23JUL2192
# Processing admissions group: Evidence 2K22JUN1714
# Processing admissions group: Tanaka 2K23JAN2309R
# Processing admissions group: Joyce 2K22OCT1382
# Processing admissions group: Takudzwa 2K22APR2585
# Processing admissions group: Timukudze 2K22DEC1272
# Processing admissions group: PATIENCE 2K22JUN2218
# Processing admissions group: Felix 2K21DEC0135
# Processing admissions group: Aureen 2K21AUG1853
# Processing admissions group: Sibonginkosi 2K21JAN1117
# Processing admissions group: Takunda 2K21JUN1628
# Processing admissions group: Kudakwashe 2K22JUN2813
# Processing admissions group: Rumbidzai 2K22APR2666
# Processing admissions group: Dylan 2K22JUN1646
# Processing admissions group: Laura 2K23FEB0392
# Processing admissions group: Isaac 2K21JUN2244
# Processing admissions group: Bridget 2K23MAY0564
# Processing admissions group: Sharon 2K20DEC1212
# Processing admissions group: Panashe 2K22JAN2212
# Processing admissions group: Paidamoyo 2K21MAR1236
# Processing admissions group: Wellington 2K22DEC3002
# Processing admissions group: Tendai 2K22AUG2312
# Processing admissions group: James 2K23JAN0228
# Processing admissions group: Nokuthaba 2K22AUG2604
# Processing admissions group: Aletta 2K22OCT0734
# Processing admissions group: Valentine 2K21FEB1545
# Processing admissions group: Theodore 2K23JAN1253
# Processing admissions group: Lenon 2K22JUN2040
# Processing admissions group: Luyanda 2K21OCT1120
# Processing admissions group: Claudett 2K22JUN0216
# Processing admissions group: TAURAI 2K22FEB1878
# Processing admissions group: Tadiwanashe 2K22DEC1355
# Processing admissions group: Humphrey 2K21SEP0180
# Processing admissions group: Caroline 2K22SEP0882
# Processing admissions group: Gamuchirai 2K21NOV1514
# Processing admissions group: Lyona 2K22JAN1236
# Processing admissions group: Keith 2K21JAN1874
# Processing admissions group: Vincent 2K23JAN0995
# Processing admissions group: Phinias 2K21JAN1650
# Processing admissions group: REBECCA 2K23JUN0964
# Processing admissions group: Francine 2K23FEB0203
# Processing admissions group: Comfort 2K21AUG2784
# Processing admissions group: Judith 2K21AUG1856
# Processing admissions group: Anotidaishe 2K23JUL0739
# Processing admissions group: Nirnoy 2K23AUG2208
# Processing admissions group: Takudzwanashe 2K23FEB0892
# Processing admissions group: Alexios 2K22MAY2124
# Processing admissions group: TINOTENDA 2K22JUN0913R
# Processing admissions group: Jubilance 2K22MAR0865
# Processing admissions group: Rachael 2K21SEP0225
# Processing admissions group: ALLAN 2K21SEP0419
# Processing admissions group: Bandile 2K19DEC1768
# Processing admissions group: Joseph EWYLJAN2058
# Processing admissions group: Samuel 2K20MAR1232
# Processing admissions group: Kuda 2K20MAR1902
# Processing admissions group: Lovejoy 2K20JUN1233
# Processing admissions group: Seddiq 2K20JUN1942
# Processing admissions group: Awuni 2K20JUN1727
# Processing admissions group: Philomena 2K20JUL1426
# Processing admissions group: Susan 2K20NOV1301
# Processing admissions group: Trish 2K20NOV2150
# Processing admissions group: James 2K21JAN0520
# Processing admissions group: Malvern 2K21FEB0839
# Processing admissions group: Mthulisi 2K21MAR1512
# Processing admissions group: Unity 2K21APR0509
# Processing admissions group: Theophilus 2K21APR2112
# Processing admissions group: Panashe 2K21JUN1428
# Processing admissions group: Tanaka 2K21JUL0238
# Processing admissions group: Martin 2K21AUG0210
# Processing admissions group: Geoff 2K21SEP0613
# Processing admissions group: Tinashe 2K21SEP2264R
# Processing admissions group: Sandra 2K21OCT0169
# Processing admissions group: Viola 2K21OCT2602
# Processing admissions group: Trudie 2K22JUN1639
# Processing admissions group: Nisar 2K20JAN0607
# Processing admissions group: Kelis 2K20JAN1664
# Processing admissions group: Nicholas 2K20JAN21
# Processing admissions group: Joy EWYLJAN2431
# Processing admissions group: Edmund 2K20JAN3075
# Processing admissions group: Gumede 2K20JAN1669
# Processing admissions group: Frederick EWYLFEB0313
# Processing admissions group: Panashe 2K20FEB1158
# Processing admissions group: Elizabeth 2K20MAR0311
# Processing admissions group: Farooq 2K20MAR1280
# Processing admissions group: Amoako 2K20APR1319
# Processing admissions group: Calton 2K20AUG2611
# Processing admissions group: Disney 2K20AUG3122
# Processing admissions group: Memory 2K20SEP0128
# Processing admissions group: Tadiwanashe 2K20SEP134
# Processing admissions group: Ryan 2K20SEP0101
# Processing admissions group: Munyaradzi 2K20SEP1107
# Processing admissions group: Silence 2K20SEP1649
# Processing admissions group: Wandile 2K20OCT0643
# Processing admissions group: Sandra 2K20OCT0941
# Processing admissions group: Brian 2K20NOV1120
# Processing admissions group: Thrive 2K20DEC1422
# Processing admissions group: Tendai 2K21JAN0827
# Processing admissions group: Zibusiso 2K21FEB0909
# Processing admissions group: Ropafadzo 2K21FEB2050
# Processing admissions group: Cynthia 2K21MAR0258
# Processing admissions group: Rufaro 2K21MAR0577
# Processing admissions group: Arnold 2K21MAR1017
# Processing admissions group: Anesu 2K21MAR2043
# Processing admissions group: Christine 2K21MAR2039
# Processing admissions group: Rumbidzai 2K21MAR2640
# Processing admissions group: Joyleen 2K21APR0268
# Processing admissions group: Gladsome 2K21MAR3101
# Processing admissions group: Wesley 2K21APR1367
# Processing admissions group: Samantha 2K21APR1450
# Processing admissions group: Sibonginkosi 2K21MAY0127
# Processing admissions group: Takudzwa 2K21MAY0404
# Processing admissions group: Tapiwa 2K21APR3027
# Processing admissions group: Shyline 2K21MAY1212
# Processing admissions group: Zanza 2K21MAY1150
# Processing admissions group: Eunick 2K21MAY0716
# Processing admissions group: Sandra 2K21MAY1077
# Processing admissions group: CHIMUSWE 2K21MAY1229
# Processing admissions group: Gavinia 2K21MAY1268
# Processing admissions group: Shepherd 2K21MAY1404
# Processing admissions group: ESNATH 2K21MAY1860
# Processing admissions group: Annatoria 2K21MAY2437
# Processing admissions group: Archival 2K21MAY2523
# Processing admissions group: Sidalubuhle 2K21MAY2402
# Processing admissions group: Sibanda 2K21JUN0345
# Processing admissions group: NYASHA 2K21JUN0976
# Processing admissions group: KUDZAYI 2K21MAY0324
# Processing admissions group: Chiturumani 2K21JUN1967
# Processing admissions group: Nyasha 2K21JUN1814
# Processing admissions group: Tanaka 2K21JUL0283
# Processing admissions group: Varaidzo 2K21JUL0532
# Processing admissions group: Isabel 2K21JUL0657
# Processing admissions group: Takudzwa 2K21JUN2575
# Processing admissions group: Nomzamo 2K21JUL1666
# Processing admissions group: Evans 2K21JUL2210
# Processing admissions group: Abraham 2K21AUG0303
# Processing admissions group: Simbarashe 2K21AUG0923
# Processing admissions group: Anna 2K22APR2085
# Processing admissions group: Tadiwanashe 2K22SEP1715
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
