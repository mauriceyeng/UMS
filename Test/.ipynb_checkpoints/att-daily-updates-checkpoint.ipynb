# %%
import nest_asyncio
nest_asyncio.apply()

import aiohttp
import asyncio
import json
import pandas as pd
from datetime import datetime 
from datetime import timedelta

# Define global variables for dataframes
student_df = None
engagement_df = None
ums_att_df = None
ums_avg_att_df = None
ums_upload_avg_att=None

# Edoofy app information
edoofy_base_url = "https://edoofa-portal.bubbleapps.io/api/1.1/obj"
edoofy_bearer_token = "2cde31d8f48919a2db1467cc06a56132"
edoofy_headers = {'Authorization': f'Bearer {edoofy_bearer_token}'}

# UMS app information
ums_base_url = "https://app.edoofa.com/api/1.1/obj"
ums_bearer_token = "786720e8eb68de7054d1149b56cc04f9"
ums_headers = {'Authorization': f'Bearer {ums_bearer_token}'}

# Asynchronous function to fetch data from a table
async def fetch_table_data(session, base_url, headers, table, constraints=None):
    records = []
    cursor = 0
    total_fetched = 0

    while True:
        params = {'limit': 100, 'cursor': cursor}
        if constraints:
            params['constraints'] = json.dumps(constraints)

        api_url = f"{base_url}/{table}"
        print(f"Fetching {table} data from {base_url}... Cursor: {cursor}")

        async with session.get(api_url, headers=headers, params=params) as response:
            if response.status != 200:
                print(f"Failed to fetch data from {table}: {await response.text()}")
                break

            data = await response.json()
            new_records = data['response']['results']
            records.extend(new_records)
            total_fetched += len(new_records)

            print(f"Fetched {len(new_records)} new records, Total fetched: {total_fetched}")

            cursor += 100

            if len(new_records) < 100:
                print(f"Exiting loop, fetched less than 100 records.")
                break

    df = pd.DataFrame(records)
    print(f"Fetched {len(df)} records for {table}.")
    return df

def map_students_to_engagement(student_df, engagement_df):
    # Ensure '_id' and 'EWYL-group-name' are in student_df
    if '_id' in student_df.columns and 'EWYL-group-name' in student_df.columns:
        student_id_to_EWYL = dict(zip(student_df['_id'], student_df['EWYL-group-name']))
        engagement_df['ewyl'] = engagement_df['student'].map(student_id_to_EWYL)
    else:
        print("Error: '_id' or 'EWYL-group-name' not in student_df columns")
    return engagement_df



def process_engagement_data(ums_att_df, engagement_df, student_df, ewyl_group):
    new_ums_df = pd.DataFrame(columns=['admissions-group-name', 'attendance-type', 'date',
                                       'ewyl-group-name', 'present', 'webinar'])
    # Create mappings
    student_to_kam_mapping = dict(zip(student_df['_id'], student_df['KAM-group-name']))
    student_to_ewyl_mapping = dict(zip(student_df['_id'], student_df['EWYL-group-name']))

    # Add KAM-group-name and ewyl columns to the engagement dataframe
    engagement_df['KAM-group-name'] = engagement_df['student'].map(student_to_kam_mapping)
    engagement_df['ewyl'] = engagement_df['student'].map(student_to_ewyl_mapping)

    # Find the latest date for the specific student in ums_att_df
    student_latest_ums_date = pd.to_datetime(ums_att_df[ums_att_df['ewyl-group-name'] == ewyl_group]['date'].max())

    if pd.isnull(student_latest_ums_date):
        # Process all records from engagement_df for this student
        new_ums_df['ewyl-group-name'] = engagement_df['ewyl']
        new_ums_df['admissions-group-name'] = engagement_df['KAM-group-name']
        new_ums_df['attendance-type'] = engagement_df['engagement-type']
        new_ums_df['date'] = engagement_df['engagement-date']
        new_ums_df['present'] = engagement_df['daily-attendance']
        
        print("Adding all records")
    else:
        # Process only records newer than the latest in ums_att_df
        filtered_engagement_df = engagement_df[pd.to_datetime(engagement_df['engagement-date']) > student_latest_ums_date]
        new_ums_df['ewyl-group-name'] = filtered_engagement_df['ewyl']
        new_ums_df['admissions-group-name'] = filtered_engagement_df['KAM-group-name']
        new_ums_df['attendance-type'] = filtered_engagement_df['engagement-type']
        new_ums_df['date'] = filtered_engagement_df['engagement-date']
        new_ums_df['present'] = filtered_engagement_df['daily-attendance']
        
        print("Adding new records")

    return new_ums_df
    

# Function to post processed engagement data
async def post_processed_data(session, base_url, headers, processed_data):
    api_url = f"{base_url}/Attendance"
    
    for index, row in processed_data.iterrows():
        data = {
            'admissions-group-name': row['admissions-group-name'],
            'ewyl-group-name': row['ewyl-group-name'],
            'attendance-type': row['attendance-type'],
            'present': row['present'],
            'date': row['date']
        }
        
        async with session.post(api_url, headers=headers, json=data) as response:
            if response.status == 201:
                print(f"Successfully posted data for row {index}")
            else:
                print(f"Failed to post data for row {index}: {await response.text()}")



def get_percentage(number_of_present, total_sessions):
    if total_sessions == 0:
        return 0  # Avoid division by zero
    percent = (number_of_present / total_sessions) * 100
    #print(percent)
    return percent

# Function to check if a row exists for the current month for a student
async def check_if_row_exists(student, year, month, ums_avg_att_df):
    # Filtering the ums_avg_att_df to check if there's an existing record for the student
    existing_rows = ums_avg_att_df[
        (ums_avg_att_df['ewyl-group-name'] == student) &
        (ums_avg_att_df['year'] == year) &
        (ums_avg_att_df['month'] == month)
    ]

    if not existing_rows.empty:
        # Assuming '_id' is the column name for the row ID
        return existing_rows['_id'].iloc[0]
    else:
        return False

# Function to post a new attendance summary
async def post_new_attendance_summary(session, base_url, headers, data):
    api_url = f"{base_url}/Attendance-Summary"
    async with session.post(api_url, headers=headers, json=data) as response:
        if response.status == 201:
            print("Successfully created a new row in Attendance-Summary.")
        else:
            print(f"Failed to create a new row: {await response.text()}")

# Function to patch an existing attendance summary
async def patch_attendance_summary(session, base_url, headers, row_id, data):
    api_url = f"{base_url}/Attendance-Summary/{row_id}"
    async with session.patch(api_url, headers=headers, json=data) as response:
        if response.status == 200:
            print("Successfully updated the row in Attendance-Summary.")
        else:
            print(f"Failed to update the row: {await response.text()}")

            
async def process_att_summary(session, base_url, headers, combined_df, ums_avg_att_df):
    att_summary_df = pd.DataFrame(columns=['admissions-group-name', 'attendance-percentage', 'avg-att-percent-till-last-month',
                                           'ewyl-group-name', 'first-day-of-month', 'month', 'year'])
    combined_df['date'] = pd.to_datetime(combined_df['date'])    
    unique_students = combined_df['admissions-group-name'].unique()

    for student in unique_students:
        student_df = combined_df[combined_df['admissions-group-name'] == student]

        # Get the earliest date in student_df for that student and set first_date as the 1st of that month
        first_date = pd.to_datetime(student_df['date'].min())
        first_day_current_month = first_date.replace(day=1)

        while True:
            this_month_df = student_df[(student_df['date'].dt.year == first_day_current_month.year) &
                                       (student_df['date'].dt.month == first_day_current_month.month)]

            prev_month_df = student_df[student_df['date'] < first_day_current_month]
            
            # Calculate attendance percentage for this month using get_percentage
            total_sessions_this_month = len(this_month_df)
            attended_sessions_this_month = this_month_df['present'].sum()  # Sum of True values in the 'present' column
            attendance_percentage_this_month = get_percentage(attended_sessions_this_month, total_sessions_this_month)

            
            # Calculate average attendance till last month
            if prev_month_df.empty:
                avg_att_till_last_month = 0
            else:
                total_sessions_till_last_month = len(prev_month_df)
                attended_sessions_till_last_month = prev_month_df['present'].sum()  # Sum of True values in the 'present' column
                avg_att_till_last_month = get_percentage(attended_sessions_till_last_month, total_sessions_till_last_month)
   
            new_row = {
                'admissions-group-name': student,
                'attendance-percentage': attendance_percentage_this_month,
                'avg-att-percent-till-last-month': avg_att_till_last_month,
                'ewyl-group-name': student_df['ewyl-group-name'].iloc[0] if not student_df['ewyl-group-name'].empty else 'N/A',
                'first-day-of-month': first_day_current_month.strftime("%Y-%m-%d"),
                'month': first_day_current_month.strftime("%B"),
                'year': first_day_current_month.year
            }
            att_summary_df = pd.concat([att_summary_df, pd.DataFrame([new_row])], ignore_index=True)
            
            # Calculate the first day of the next month
            next_month_first_day = (first_day_current_month + pd.offsets.MonthBegin()).normalize()
            
            # Update first_day_current_month to the first day of the next month
            first_day_current_month = next_month_first_day
            
            # Check if there is data for the next month
            if student_df[student_df['date'] >= first_day_current_month].empty:
                break              

        for index, row in att_summary_df.iterrows():
                row_id = await check_if_row_exists(row['ewyl-group-name'], row['year'], row['month'], ums_avg_att_df)

                data = {
                    'admissions-group-name': row['admissions-group-name'],
                    'attendance-percentage': row['attendance-percentage'],
                    'avg-att-percent-till-last-month': row['avg-att-percent-till-last-month'],
                    'ewyl-group-name': row['ewyl-group-name'],  
                    'first-day-of-month': row['first-day-of-month'],  
                    'month': row['month'],  
                    'year': row['year']  
                }

                # Convert any Pandas Series or non-serializable types to native Python types
                for key, value in data.items():
                    if isinstance(value, pd.Series):
                        data[key] = value.iloc[0]  # Assuming you want the first element of the Series

                if row_id:
                    await patch_attendance_summary(session, base_url, headers, row_id, data)
                    print("patch function")
                else:
                    await post_new_attendance_summary(session, base_url, headers, data)
                    print("post function")

    return att_summary_df


async def main():
    global student_df, engagement_this_month_df, engagement_previous_months_df, ums_att_df, ums_avg_att_df
    
    async with aiohttp.ClientSession() as session:
        # Fetch data from 'ums_att'
        ums_att_df = await fetch_table_data(session, ums_base_url, ums_headers, "Attendance")
        
        ums_avg_att_df = await fetch_table_data(session, ums_base_url, ums_headers, "Attendance-Summary")
        
        # Determine the latest date from 'ums_att'
        ums_latest = pd.to_datetime(ums_att_df['date'].max())
        
        # Fetch Student table from Edoofy -enter student row id
        student_constraints = [           
            {'key': 'indian-edoofian', 'constraint_type': 'equals', 'value': 'yes'}
        ]
        student_df = await fetch_table_data(session, edoofy_base_url, edoofy_headers, "Student", constraints=student_constraints)
        
        # Fetch engagement data where 'engagement-date' is greater than 'ums_latest'
        engagement_constraints = [
            #{'key': 'engagement-date', 'constraint_type': 'greater than', 'value': ums_latest.isoformat()},
            {'key': 'engagement-type', 'constraint_type': 'equals', 'value': 'IE Call',
             'key': 'engagement-type', 'constraint_type': 'equals', 'value': 'IE Chat',
             'key': 'engagement-type', 'constraint_type': 'equals', 'value': 'Activity',
             'key': 'engagement-type', 'constraint_type': 'equals', 'value': 'Lesson'
            }
        ]
        engagement_df = await fetch_table_data(session, edoofy_base_url, edoofy_headers, "Engagement", constraints=engagement_constraints)
        #engagement_df = engagement_df[engagement_df['engagement-type'].isin(['IE Call', 'IE Chat', 'Activity', 'Lesson'])]
        
        # Calculate the start and end date for the till last month (excluding this month)
        latest_engagement_date = pd.to_datetime(engagement_df['engagement-date'].max())
        end_date = latest_engagement_date.replace(day=1) - timedelta(days=1)
       # start_date = end_date - timedelta(days=365)

        # Filter engagement data for the till last month
        previous_months_df = engagement_df[            
            (pd.to_datetime(engagement_df['engagement-date']) <= end_date)
        ]

        # Split the data into this month and previous months
        this_month_start = latest_engagement_date.replace(day=1)
        engagement_this_month_df = engagement_df[
            pd.to_datetime(engagement_df['engagement-date']) >= this_month_start
        ]
        engagement_previous_months_df = previous_months_df
        
        # Apply mapping to engagement dataframes
        engagement_this_month_df = map_students_to_engagement(student_df, engagement_this_month_df)
        engagement_previous_months_df = map_students_to_engagement(student_df, engagement_previous_months_df)
        
        all_processed_data = []

        for _, student_row in student_df.iterrows():
            ewyl_group = student_row['EWYL-group-name']
            processed_df = process_engagement_data(ums_att_df, engagement_df, student_df, ewyl_group)

            if not processed_df.empty:
                await post_processed_data(session, ums_base_url, ums_headers, processed_df)
                all_processed_data.append(processed_df)
            else:
                print(f"No data to post for student {ewyl_group}")

            # Delay between students
            print("1 second buffer before proceeding...")
            await asyncio.sleep(1)

        # After the loop, concatenate only the processed data
        if all_processed_data:
            combined_df = pd.concat(all_processed_data, ignore_index=True)
        else:
            combined_df = pd.DataFrame()
        print("New Attendance data posted in UMS... proceeding with Attendance-Summary")
        
        # Process attendance summary
        await process_att_summary(session, ums_base_url, ums_headers, combined_df, ums_avg_att_df)


await main()
# Out:
# Fetching Attendance data from https://app.edoofa.com/api/1.1/obj... Cursor: 0
# Fetched 1 new records, Total fetched: 1
# Exiting loop, fetched less than 100 records.
# Fetched 1 records for Attendance.
# Fetching Attendance-Summary data from https://app.edoofa.com/api/1.1/obj... Cursor: 0
# Fetched 1 new records, Total fetched: 1
# Exiting loop, fetched less than 100 records.
# Fetched 1 records for Attendance-Summary.
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 0
# Fetched 100 new records, Total fetched: 100
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 100
# Fetched 100 new records, Total fetched: 200
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 200
# Fetched 100 new records, Total fetched: 300
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 300
# Fetched 100 new records, Total fetched: 400
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 400
# Fetched 100 new records, Total fetched: 500
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 500
# Fetched 100 new records, Total fetched: 600
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 600
# Fetched 100 new records, Total fetched: 700
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 700
# Fetched 100 new records, Total fetched: 800
# Fetching Student data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 800
# Fetched 19 new records, Total fetched: 819
# Exiting loop, fetched less than 100 records.
# Fetched 819 records for Student.
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 0
# Fetched 100 new records, Total fetched: 100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 100
# Fetched 100 new records, Total fetched: 200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 200
# Fetched 100 new records, Total fetched: 300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 300
# Fetched 100 new records, Total fetched: 400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 400
# Fetched 100 new records, Total fetched: 500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 500
# Fetched 100 new records, Total fetched: 600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 600
# Fetched 100 new records, Total fetched: 700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 700
# Fetched 100 new records, Total fetched: 800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 800
# Fetched 100 new records, Total fetched: 900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 900
# Fetched 100 new records, Total fetched: 1000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1000
# Fetched 100 new records, Total fetched: 1100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1100
# Fetched 100 new records, Total fetched: 1200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1200
# Fetched 100 new records, Total fetched: 1300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1300
# Fetched 100 new records, Total fetched: 1400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1400
# Fetched 100 new records, Total fetched: 1500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1500
# Fetched 100 new records, Total fetched: 1600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1600
# Fetched 100 new records, Total fetched: 1700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1700
# Fetched 100 new records, Total fetched: 1800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1800
# Fetched 100 new records, Total fetched: 1900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 1900
# Fetched 100 new records, Total fetched: 2000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2000
# Fetched 100 new records, Total fetched: 2100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2100
# Fetched 100 new records, Total fetched: 2200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2200
# Fetched 100 new records, Total fetched: 2300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2300
# Fetched 100 new records, Total fetched: 2400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2400
# Fetched 100 new records, Total fetched: 2500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2500
# Fetched 100 new records, Total fetched: 2600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2600
# Fetched 100 new records, Total fetched: 2700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2700
# Fetched 100 new records, Total fetched: 2800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2800
# Fetched 100 new records, Total fetched: 2900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 2900
# Fetched 100 new records, Total fetched: 3000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3000
# Fetched 100 new records, Total fetched: 3100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3100
# Fetched 100 new records, Total fetched: 3200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3200
# Fetched 100 new records, Total fetched: 3300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3300
# Fetched 100 new records, Total fetched: 3400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3400
# Fetched 100 new records, Total fetched: 3500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3500
# Fetched 100 new records, Total fetched: 3600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3600
# Fetched 100 new records, Total fetched: 3700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3700
# Fetched 100 new records, Total fetched: 3800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3800
# Fetched 100 new records, Total fetched: 3900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 3900
# Fetched 100 new records, Total fetched: 4000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4000
# Fetched 100 new records, Total fetched: 4100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4100
# Fetched 100 new records, Total fetched: 4200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4200
# Fetched 100 new records, Total fetched: 4300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4300
# Fetched 100 new records, Total fetched: 4400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4400
# Fetched 100 new records, Total fetched: 4500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4500
# Fetched 100 new records, Total fetched: 4600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4600
# Fetched 100 new records, Total fetched: 4700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4700
# Fetched 100 new records, Total fetched: 4800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4800
# Fetched 100 new records, Total fetched: 4900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 4900
# Fetched 100 new records, Total fetched: 5000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5000
# Fetched 100 new records, Total fetched: 5100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5100
# Fetched 100 new records, Total fetched: 5200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5200
# Fetched 100 new records, Total fetched: 5300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5300
# Fetched 100 new records, Total fetched: 5400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5400
# Fetched 100 new records, Total fetched: 5500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5500
# Fetched 100 new records, Total fetched: 5600
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5600
# Fetched 100 new records, Total fetched: 5700
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5700
# Fetched 100 new records, Total fetched: 5800
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5800
# Fetched 100 new records, Total fetched: 5900
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 5900
# Fetched 100 new records, Total fetched: 6000
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 6000
# Fetched 100 new records, Total fetched: 6100
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 6100
# Fetched 100 new records, Total fetched: 6200
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 6200
# Fetched 100 new records, Total fetched: 6300
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 6300
# Fetched 100 new records, Total fetched: 6400
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 6400
# Fetched 100 new records, Total fetched: 6500
# Fetching Engagement data from https://edoofa-portal.bubbleapps.io/api/1.1/obj... Cursor: 6500
# Fetched 41 new records, Total fetched: 6541
# Exiting loop, fetched less than 100 records.
# Fetched 6541 records for Engagement.
# Adding all records
# C:\Users\mauri\AppData\Local\Temp\ipykernel_25260\3158841121.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   engagement_df['ewyl'] = engagement_df['student'].map(student_id_to_EWYL)
# C:\Users\mauri\AppData\Local\Temp\ipykernel_25260\3158841121.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   engagement_df['ewyl'] = engagement_df['student'].map(student_id_to_EWYL)
# Failed to post data for row 0: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423955865x144823405408133440
# Failed to post data for row 1: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423956753x160025791475187040
# Failed to post data for row 2: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423957654x861882903329469500
# Failed to post data for row 3: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423958557x437975900754645800
# Successfully posted data for row 4
# Failed to post data for row 5: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423960557x621956781805145900
# Failed to post data for row 6: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423961460x800425530915159800
# Failed to post data for row 7: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423962348x931007646311416600
# Failed to post data for row 8: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423963233x702469399850967900
# Successfully posted data for row 9
# Failed to post data for row 10: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423965086x232782445851111840
# Failed to post data for row 11: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423966092x674487225732841600
# Failed to post data for row 12: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423966977x133846785851152720
# Successfully posted data for row 13
# Failed to post data for row 14: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423968862x682300928590014600
# Successfully posted data for row 15
# Failed to post data for row 16: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423970756x170901332775353250
# Failed to post data for row 17: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423971652x352416186890141630
# Failed to post data for row 18: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423972550x986911079179300500
# Failed to post data for row 19: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423973438x959184009388187600
# Failed to post data for row 20: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423974318x484520714623691400
# Successfully posted data for row 21
# Failed to post data for row 22: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423976199x809051315041343600
# Failed to post data for row 23: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423977096x606817601010819300
# Successfully posted data for row 24
# Failed to post data for row 25: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423979041x889375742064805900
# Failed to post data for row 26: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423979931x472788378813520100
# Failed to post data for row 27: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423980836x733166196981453300
# Failed to post data for row 28: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423981725x757816475386432500
# Failed to post data for row 29: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423982612x294966127072980000
# Failed to post data for row 30: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423983492x758591245334649100
# Failed to post data for row 31: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423984371x339886506204290800
# Failed to post data for row 32: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423985249x807141010509156100
# Failed to post data for row 33: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423986166x126178064654584030
# Failed to post data for row 34: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423987055x629434132231836800
# Failed to post data for row 35: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423987966x239901314894984450
# Failed to post data for row 36: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423988863x799333338121046800
# Successfully posted data for row 37
# Failed to post data for row 38: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423990668x284032175967634750
# Failed to post data for row 39: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423991589x693048941106082500
# Failed to post data for row 40: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423992507x866405191120783100
# Failed to post data for row 41: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423993414x888582037738264700
# Successfully posted data for row 42
# Failed to post data for row 43: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423995237x521830120910366600
# Failed to post data for row 44: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423996126x783555564036835100
# Failed to post data for row 45: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423997040x591466053978866000
# Successfully posted data for row 46
# Failed to post data for row 47: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423998894x908429144741709200
# Failed to post data for row 48: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708423999801x598190723190687100
# Failed to post data for row 49: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424000692x970091121952012500
# Failed to post data for row 50: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424001602x517817825554261570
# Failed to post data for row 51: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424002493x546909988037724800
# Failed to post data for row 52: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424003366x332642025153475650
# Failed to post data for row 53: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424004254x895210866978518800
# Failed to post data for row 54: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424005145x648066341668124000
# Failed to post data for row 55: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424005985x557194702633763140
# Failed to post data for row 56: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424006873x632723906608412900
# Failed to post data for row 57: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424007769x299928873830692400
# Failed to post data for row 58: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424008657x810398827111441000
# Failed to post data for row 59: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424009552x371809671232700350
# Failed to post data for row 60: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424010435x758640481292976400
# Failed to post data for row 61: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424011284x846000544115801400
# Failed to post data for row 62: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424012164x587191351002794400
# Failed to post data for row 63: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424013125x709643362793910700
# Failed to post data for row 64: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424014003x748616396926170800
# Failed to post data for row 65: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424014883x420659912749037800
# Successfully posted data for row 66
# Failed to post data for row 67: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424016750x561865970801146430
# Failed to post data for row 68: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424017636x402599652625368100
# Failed to post data for row 69: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424018512x561901259069660600
# Failed to post data for row 70: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424019392x754050739947611000
# Failed to post data for row 71: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424020282x589952600927547800
# Successfully posted data for row 72
# Failed to post data for row 73: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424022102x861022248416665500
# Failed to post data for row 74: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424022997x423268552438078140
# Successfully posted data for row 75
# Failed to post data for row 76: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424024833x433569741035870800
# Failed to post data for row 77: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424025703x219423563249022000
# Successfully posted data for row 78
# Failed to post data for row 79: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424027512x293355515240597570
# Successfully posted data for row 80
# Successfully posted data for row 81
# Failed to post data for row 82: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424030846x981286817413483000
# Failed to post data for row 83: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424031744x313703677716946900
# Successfully posted data for row 84
# Failed to post data for row 85: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424033597x881446135101518000
# Successfully posted data for row 86
# Failed to post data for row 87: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424035480x431683482121906000
# Successfully posted data for row 88
# Failed to post data for row 89: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424037308x419866951240440260
# Successfully posted data for row 90
# Failed to post data for row 91: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424039125x194411807839408400
# Failed to post data for row 92: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424040001x123665129483782720
# Failed to post data for row 93: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424040888x243694077067986530
# Failed to post data for row 94: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424041770x906175587297141100
# Successfully posted data for row 95
# Failed to post data for row 96: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424043642x231046964931520770
# Successfully posted data for row 97
# Failed to post data for row 98: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424045505x357766896389932100
# Failed to post data for row 99: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424046397x783078216678058400
# Successfully posted data for row 100
# Successfully posted data for row 101
# Failed to post data for row 102: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424049237x979510565983499800
# Successfully posted data for row 103
# Successfully posted data for row 104
# Failed to post data for row 105: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424052093x310195437853331140
# Successfully posted data for row 106
# Failed to post data for row 107: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424053931x652912545133133040
# Failed to post data for row 108: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424054854x661946637474171400
# Successfully posted data for row 109
# Successfully posted data for row 110
# Failed to post data for row 111: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424057717x108455553062838160
# Failed to post data for row 112: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424058630x542489761141309760
# Failed to post data for row 113: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424059513x340312443793912000
# Failed to post data for row 114: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424060413x434388078081411140
# Failed to post data for row 115: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424061303x116584253420845220
# Failed to post data for row 116: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424062202x691771429626324600
# Successfully posted data for row 117
# Failed to post data for row 118: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424064050x881103071254490100
# Failed to post data for row 119: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424064947x846595624460251800
# Failed to post data for row 120: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424065855x418920865130287360
# Failed to post data for row 121: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424066755x399326536993797950
# Failed to post data for row 122: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424067633x656048517920924200
# Failed to post data for row 123: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424068523x625548237868967200
# Failed to post data for row 124: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424069422x483077054451364100
# Successfully posted data for row 125
# Failed to post data for row 126: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424071291x295327568343004100
# Failed to post data for row 127: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424072195x141126393346474820
# Failed to post data for row 128: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424073110x323679811716253400
# Failed to post data for row 129: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424073964x706740493243146900
# Failed to post data for row 130: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424074862x336219762504343940
# Failed to post data for row 131: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424075770x245123675178069660
# Failed to post data for row 132: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424076675x130220041201302370
# Failed to post data for row 133: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424077554x590713548359331300
# Successfully posted data for row 134
# Failed to post data for row 135: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424079366x855287536765390000
# Failed to post data for row 136: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424080260x193348619381396260
# Failed to post data for row 137: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424081163x778724081959590100
# Failed to post data for row 138: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424082042x573195481386845400
# Failed to post data for row 139: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424082918x900310321561346400
# Failed to post data for row 140: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424083791x555352650242795200
# Failed to post data for row 141: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424084664x681557517583589200
# Failed to post data for row 142: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424085569x813058530550514500
# Failed to post data for row 143: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424086471x630709604066249900
# Failed to post data for row 144: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424087356x246262910583088930
# Failed to post data for row 145: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424088236x222299914739726200
# Failed to post data for row 146: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424089156x870924135366470900
# Failed to post data for row 147: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424090068x534263774326097400
# Failed to post data for row 148: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424090959x681430451328681700
# Successfully posted data for row 149
# Failed to post data for row 150: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424092810x264000693896431200
# Failed to post data for row 151: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424093689x192735025770427460
# Failed to post data for row 152: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424094566x670585609447582300
# Failed to post data for row 153: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424095477x501811811967311000
# Failed to post data for row 154: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424096367x464265679312715300
# Failed to post data for row 155: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424097244x819985918913592600
# Successfully posted data for row 156
# Failed to post data for row 157: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424099087x510512982400632450
# Failed to post data for row 158: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424099962x689144549686659300
# Failed to post data for row 159: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424100847x899102770161149600
# Failed to post data for row 160: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424101743x752574016081455100
# Failed to post data for row 161: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424102647x520167758148562600
# Failed to post data for row 162: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424103565x347012819248836860
# Failed to post data for row 163: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424104459x766099614311879400
# Failed to post data for row 164: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424105326x933081797003877600
# Failed to post data for row 165: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424106213x667886801365313000
# Failed to post data for row 166: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424107102x490295656127911040
# Failed to post data for row 167: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424108011x893145949534820200
# Failed to post data for row 168: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424108904x848816817726715000
# Failed to post data for row 169: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424109796x886904781423563500
# Successfully posted data for row 170
# Failed to post data for row 171: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424111639x663123576146682200
# Failed to post data for row 172: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424112516x855902644463468800
# Failed to post data for row 173: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424113418x222047559551147300
# Successfully posted data for row 174
# Failed to post data for row 175: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424115291x239264575458183260
# Failed to post data for row 176: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424116183x117250985588559730
# Failed to post data for row 177: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424117074x710045872470901800
# Failed to post data for row 178: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424117975x329249072683644350
# Failed to post data for row 179: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424118867x346418722446432600
# Failed to post data for row 180: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424119759x291857925761439100
# Failed to post data for row 181: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424120645x986507006028209000
# Failed to post data for row 182: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424121536x345954168868894700
# Failed to post data for row 183: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424122430x827779683021248300
# Failed to post data for row 184: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424123312x448761673028621400
# Failed to post data for row 185: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424124228x260634924783855740
# Failed to post data for row 186: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424125138x788771572749774800
# Successfully posted data for row 187
# Failed to post data for row 188: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424126926x640324467700412000
# Failed to post data for row 189: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424127844x496016711206876300
# Failed to post data for row 190: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424128729x430568020905004700
# Failed to post data for row 191: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424129619x268567606373862240
# Successfully posted data for row 192
# Failed to post data for row 193: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424131477x613543084176222600
# Failed to post data for row 194: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424132370x481139341976783100
# Failed to post data for row 195: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424133282x339340201449232600
# Failed to post data for row 196: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424134188x576918882092333200
# Failed to post data for row 197: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424135063x326713478918696700
# Failed to post data for row 198: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424135931x794412595615812600
# Failed to post data for row 199: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424136830x481593989668490430
# Failed to post data for row 200: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424137737x246866360706987870
# Failed to post data for row 201: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424138635x475483313935827650
# Successfully posted data for row 202
# Successfully posted data for row 203
# Failed to post data for row 204: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424141549x524094830455725100
# Failed to post data for row 205: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424142453x969635179835477400
# Successfully posted data for row 206
# Failed to post data for row 207: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424144282x967082337934365800
# Failed to post data for row 208: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424145180x256575528134071800
# Failed to post data for row 209: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424146071x425249836421715200
# Failed to post data for row 210: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424146941x734255384411628700
# Successfully posted data for row 211
# Failed to post data for row 212: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424148766x896665882437514600
# Failed to post data for row 213: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424149634x297336806372128450
# Failed to post data for row 214: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424150520x593402288331134700
# Successfully posted data for row 215
# Successfully posted data for row 216
# Failed to post data for row 217: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424153402x140124521023834440
# Failed to post data for row 218: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424154306x274610009156185820
# Successfully posted data for row 219
# Failed to post data for row 220: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424156123x568970997185633150
# Failed to post data for row 221: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424156999x377968936521623700
# Failed to post data for row 222: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424157876x489655811706394700
# Failed to post data for row 223: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424158746x525014939827750850
# Successfully posted data for row 224
# Failed to post data for row 225: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424160600x925518153790072700
# Failed to post data for row 226: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424161493x967828835444623200
# Failed to post data for row 227: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424162373x745140799178201500
# Failed to post data for row 228: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424163247x273373633091059870
# Failed to post data for row 229: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424164137x877538413692340700
# Failed to post data for row 230: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424165028x900770752827633900
# Failed to post data for row 231: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424165932x730784989527773200
# Failed to post data for row 232: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424166861x186763464219334100
# Failed to post data for row 233: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424167758x801179063252535900
# Failed to post data for row 234: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424168666x307642135163480100
# Failed to post data for row 235: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424169555x733690786871981600
# Successfully posted data for row 236
# Failed to post data for row 237: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424171533x217715738527993540
# Failed to post data for row 238: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424172395x245672720277394520
# Failed to post data for row 239: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424173303x451144368036213950
# Failed to post data for row 240: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424174200x164650860737729950
# Failed to post data for row 241: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424175119x227939968610846080
# Failed to post data for row 242: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424176012x120427457256432560
# Failed to post data for row 243: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424176908x198079614696716100
# Failed to post data for row 244: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424177791x282707722634612860
# Failed to post data for row 245: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424178678x441769590766315970
# Failed to post data for row 246: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424179562x915582784667987600
# Failed to post data for row 247: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424180467x692408917805042960
# Failed to post data for row 248: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424181384x344665758027578040
# Failed to post data for row 249: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424182302x978046179436777900
# Failed to post data for row 250: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424183200x128013472445893680
# Failed to post data for row 251: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424184109x460448547628375900
# Failed to post data for row 252: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424185010x361587431530275600
# Failed to post data for row 253: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424185921x638647439130121300
# Failed to post data for row 254: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424186816x948617950542774100
# Failed to post data for row 255: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424187702x979567129925216900
# Failed to post data for row 256: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424188589x284548705678455260
# Failed to post data for row 257: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424189471x990897867030588800
# Failed to post data for row 258: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424190353x962822808060264000
# Failed to post data for row 259: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424191249x666342058552691000
# Failed to post data for row 260: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424192149x692357665616300700
# Failed to post data for row 261: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424193024x244852954550070400
# Failed to post data for row 262: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424193916x160896709343435040
# Successfully posted data for row 263
# Failed to post data for row 264: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424195756x773892958435004700
# Failed to post data for row 265: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424196673x651871228265740400
# Failed to post data for row 266: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424197586x660186366645314000
# Failed to post data for row 267: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424198511x355872346218292700
# Failed to post data for row 268: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424199412x638148365791921200
# Failed to post data for row 269: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424200308x835846599114983700
# Failed to post data for row 270: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424201192x681138310129177200
# Failed to post data for row 271: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424202065x966807729943119900
# Failed to post data for row 272: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424202967x188196299371254500
# Successfully posted data for row 273
# Failed to post data for row 274: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424204816x755432591453571100
# Failed to post data for row 275: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424205688x309268443117702840
# Failed to post data for row 276: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424206586x116255254787373200
# Failed to post data for row 277: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708424207463x252615092730308360
# ...
#
# Code: 1708426974098x116495962233403860
# Failed to post data for row 3379: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426974983x593916151090683100
# Failed to post data for row 3380: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426975858x465679663127711170
# Successfully posted data for row 3381
# Failed to post data for row 3382: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426977676x311744665787594430
# Failed to post data for row 3383: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426978564x690049743206040400
# Failed to post data for row 3384: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426979470x725679735854716000
# Failed to post data for row 3385: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426980372x574575372562883700
# Failed to post data for row 3386: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426981278x752513099161797400
# Failed to post data for row 3387: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426982224x132176758159714190
# Failed to post data for row 3388: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426983118x340039889214228500
# Failed to post data for row 3389: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426984002x624432267605858200
# Failed to post data for row 3390: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426984876x862844281727377500
# Failed to post data for row 3391: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426985775x449012424449726660
# Failed to post data for row 3392: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426986658x662212933231475800
# Failed to post data for row 3393: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426987538x462561646915794700
# Failed to post data for row 3394: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426988419x823593902705431600
# Failed to post data for row 3395: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426989321x199758277932798660
# Failed to post data for row 3396: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426990216x875625207508443600
# Failed to post data for row 3397: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426991096x760148788897795300
# Failed to post data for row 3398: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426991968x530282548040330600
# Failed to post data for row 3399: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426992888x715461943245944200
# Failed to post data for row 3400: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426993794x699301996893630960
# Failed to post data for row 3401: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426994692x387259048478958200
# Failed to post data for row 3402: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426995572x904924242471962800
# Failed to post data for row 3403: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426996465x352205256010543740
# Failed to post data for row 3404: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426997371x258028134555470460
# Failed to post data for row 3405: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426998265x923256704747465600
# Failed to post data for row 3406: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708426999145x806951010355255600
# Failed to post data for row 3407: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427000047x835084791388760500
# Failed to post data for row 3408: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427000918x482407189940103230
# Failed to post data for row 3409: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427001788x408694401166943800
# Failed to post data for row 3410: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427002676x177100223645534340
# Failed to post data for row 3411: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427003551x628531569746226400
# Failed to post data for row 3412: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427004422x776861388354510000
# Failed to post data for row 3413: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427005327x387441617945499600
# Failed to post data for row 3414: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427006213x170370483872350750
# Failed to post data for row 3415: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427007100x509110087964474960
# Failed to post data for row 3416: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427007976x510434977221585700
# Failed to post data for row 3417: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427008863x783649238830585100
# Failed to post data for row 3418: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427009752x890707099013400400
# Failed to post data for row 3419: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427010631x879597383727324900
# Failed to post data for row 3420: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427011496x781396724931027200
# Failed to post data for row 3421: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427012373x705787510943942700
# Failed to post data for row 3422: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427013256x238233575989141630
# Failed to post data for row 3423: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427014136x126504061000647600
# Failed to post data for row 3424: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427015021x855188424183992200
# Failed to post data for row 3425: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427015900x848109406194198900
# Failed to post data for row 3426: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427016815x890867386855334500
# Failed to post data for row 3427: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427017693x961170498700096000
# Failed to post data for row 3428: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427018572x961409659655098100
# Failed to post data for row 3429: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427019449x640953060073470300
# Failed to post data for row 3430: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427020325x818179137084688300
# Failed to post data for row 3431: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427021209x611004419629530500
# Failed to post data for row 3432: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427022108x499168444852467800
# Failed to post data for row 3433: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427022999x555604482652749500
# Failed to post data for row 3434: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427023878x195504529776867170
# Failed to post data for row 3435: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427024775x756098029489615800
# Failed to post data for row 3436: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427025642x673793168297227800
# Failed to post data for row 3437: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427026542x885629381654946000
# Successfully posted data for row 3438
# Failed to post data for row 3439: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427028344x362091546420003650
# Failed to post data for row 3440: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427029226x792623377403852000
# Failed to post data for row 3441: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427030099x415621438207832500
# Failed to post data for row 3442: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427030997x851534160805693700
# Failed to post data for row 3443: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427031869x655205618001251600
# Failed to post data for row 3444: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427032746x792057057507840800
# Failed to post data for row 3445: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427033636x275338218958545600
# Failed to post data for row 3446: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427034505x355936328730600770
# Failed to post data for row 3447: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427035381x285513322627951140
# Failed to post data for row 3448: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427036287x178456922061230430
# Failed to post data for row 3449: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427037149x733249845610611800
# Failed to post data for row 3450: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427038016x582140234952335200
# Failed to post data for row 3451: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427038902x984913228509843600
# Failed to post data for row 3452: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427039806x450739390511050600
# Failed to post data for row 3453: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427040686x280552531515080960
# Failed to post data for row 3454: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427041556x230071483228075900
# Failed to post data for row 3455: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427042424x747468340404682200
# Failed to post data for row 3456: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427043324x855279616948685300
# Failed to post data for row 3457: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427044215x603085376242625400
# Failed to post data for row 3458: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427045098x624111255691941900
# Failed to post data for row 3459: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427045968x385572145967176600
# Failed to post data for row 3460: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427046858x577553299643381400
# Failed to post data for row 3461: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427047769x483887469970226700
# Failed to post data for row 3462: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427048662x851359334028568300
# Failed to post data for row 3463: Error: Error parsing request body: Unexpected token N in JSON at position 26
#
# Code: 1708427049544x370178392890317500
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[1], line 334
#     330         # Process attendance summary
#     331         await process_att_summary(session, ums_base_url, ums_headers, combined_df, ums_avg_att_df)
# --> 334 await main()
#
# Cell In[1], line 314, in main()
#     311 processed_df = process_engagement_data(ums_att_df, engagement_df, student_df, ewyl_group)
#     313 if not processed_df.empty:
# --> 314     await post_processed_data(session, ums_base_url, ums_headers, processed_df)
#     315     all_processed_data.append(processed_df)
#     316 else:
#
# Cell In[1], line 125, in post_processed_data(session, base_url, headers, processed_data)
#     116 for index, row in processed_data.iterrows():
#     117     data = {
#     118         'admissions-group-name': row['admissions-group-name'],
#     119         'ewyl-group-name': row['ewyl-group-name'],
#    (...)
#     122         'date': row['date']
#     123     }
# --> 125     async with session.post(api_url, headers=headers, json=data) as response:
#     126         if response.status == 201:
#     127             print(f"Successfully posted data for row {index}")
#
# File ~\anaconda3\Lib\site-packages\aiohttp\client.py:1141, in _BaseRequestContextManager.__aenter__(self)
#    1140 async def __aenter__(self) -> _RetType:
# -> 1141     self._resp = await self._coro
#    1142     return self._resp
#
# File ~\anaconda3\Lib\site-packages\aiohttp\client.py:560, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, proxy_headers, trace_request_ctx, read_bufsize)
#     558 resp = await req.send(conn)
#     559 try:
# --> 560     await resp.start(conn)
#     561 except BaseException:
#     562     resp.close()
#
# File ~\anaconda3\Lib\site-packages\aiohttp\client_reqrep.py:899, in ClientResponse.start(self, connection)
#     897 try:
#     898     protocol = self._protocol
# --> 899     message, payload = await protocol.read()  # type: ignore[union-attr]
#     900 except http.HttpProcessingError as exc:
#     901     raise ClientResponseError(
#     902         self.request_info,
#     903         self.history,
#    (...)
#     906         headers=exc.headers,
#     907     ) from exc
#
# File ~\anaconda3\Lib\site-packages\aiohttp\streams.py:616, in DataQueue.read(self)
#     614 self._waiter = self._loop.create_future()
#     615 try:
# --> 616     await self._waiter
#     617 except (asyncio.CancelledError, asyncio.TimeoutError):
#     618     self._waiter = None
#
# File ~\anaconda3\Lib\asyncio\futures.py:287, in Future.__await__(self)
#     285 if not self.done():
#     286     self._asyncio_future_blocking = True
# --> 287     yield self  # This tells Task to wait for completion.
#     288 if not self.done():
#     289     raise RuntimeError("await wasn't used with future")
#
# File ~\anaconda3\Lib\asyncio\futures.py:198, in Future.result(self)
#     196 if self._state == _CANCELLED:
#     197     exc = self._make_cancelled_error()
# --> 198     raise exc
#     199 if self._state != _FINISHED:
#     200     raise exceptions.InvalidStateError('Result is not ready.')
#
# CancelledError:

# %%
print(combined_df)

# %%
# !jt -r
# Out:
# Reset css and font defaults in:
# C:\Users\mauri\.jupyter\custom &
# C:\Users\mauri\AppData\Roaming\jupyter\nbextensions

# %%
# !jt -t monokai
