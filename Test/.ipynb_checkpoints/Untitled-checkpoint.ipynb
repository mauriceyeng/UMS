# %%
async def process_att_summary(session, base_url, headers, combined_df, ums_avg_att_df):
    this_month_df = pd.DataFrame(columns=['admissions-group-name', 'attendance-type', 'date',
                                       'ewyl-group-name', 'present', 'webinar'])
    prev_month_df = pd.DataFrame(columns=['admissions-group-name', 'attendance-type', 'date',
                                       'ewyl-group-name', 'present', 'webinar'])
    
    latest_engagement_date = pd.to_datetime(combined_df['date'].max())
    current_year = latest_engagement_date.year
    current_month = latest_engagement_date.strftime("%B")
    first_day_of_month = latest_engagement_date.replace(day=1).strftime("%Y-%m-%d")   
    
    unique_students = combined_df['admissions-group-name'].unique() 
    
    for student in unique_students:
    
        #initialize the headers of the att_summary_df
        att_summary_df = pd.DataFrame(columns=['admissions-group-name', 'attendance-percentage', 'avg-att-percent-till-last-month',
                                       'ewyl-group-name', 'first-day-of-month', 'month', 'year'])
        
        student_df = combined_df[combined_df['admissions-group-name'] == student]
        
        #get the earliest date in combined_df for that student and set first_date as the 1st of that month
        first_date = pd.to_datetime(combined_df['date'].min())
        first_day_of_month = first_date.replace(day=1)        
        
        #get the month for that and 
            #set this_month_df as all the rows in combined_df for that month
            #set the prev_month_df as the rows in combined_df for all dates less than the first date
        
        current_month = first_date.strftime("%B")
        this_month_df = student_df[(student_df['date'].dt.year == first_day_of_month.year) &
                                   (student_df['date'].dt.month == first_day_of_month.month)]

        prev_month_df = student_df[student_df['date'] < first_day_of_month]

        
        #set the values of att_summary_df (all coulumns as per combined df). 
        
        # Calculate attendance percentage for this month using get_percentage
        total_sessions_this_month = len(this_month_df)
        attended_sessions_this_month = this_month_df[this_month_df['present'] == 'Present'].count()  # Replace 'attendance_status' and 'Present' with actual values
        attendance_percentage_this_month = get_percentage(attended_sessions_this_month, total_sessions_this_month)
        
        #att_till_last_month  = if prev_month_df is empty this is 0. 
        #for att_percentage_this_month, caluclate total sessions and total present in this_month_df and set the value accordingly
        
        # Calculate average attendance till last month
        if prev_month_df.empty:
            avg_att_till_last_month = 0
        else:
            total_sessions_till_last_month = len(prev_month_df)
            attended_sessions_till_last_month = prev_month_df[prev_month_df['present'] == 'Present'].count()  # Adjust as necessary
            avg_att_till_last_month = get_percentage(attended_sessions_till_last_month, total_sessions_till_last_month)
        
         new_row = {
        'admissions-group-name': student,
        'attendance-percentage': attendance_percentage_this_month,
        'avg-att-percent-till-last-month': avg_att_till_last_month,
        'ewyl-group-name': student_df['ewyl-group-name'].iloc[0],  # Assuming the value is same across all rows for the student
        'first-day-of-month': first_day_current_month.strftime("%Y-%m-%d"),  # Formatting to string if needed
        'month': first_day_current_month.strftime("%B"),  # Extracts the month name
        'year': first_day_current_month.year  # Extracts the year
        }
        
        att_summary_df = att_summary_df.append(new_row, ignore_index=True)

        #get the first date for the next month
        #rerun the loop
        
        #populate prev_month_df and calculate percentage
            #call function to post
